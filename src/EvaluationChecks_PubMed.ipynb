# %%
#############################################################################################################
# Extracting chemical-disease associations from the biological literature
# R214: Main Practical
# Jan Ondras (jo356), Trinity College
#############################################################################################################
# Check agreement between NE tags and matched concept types (target PubMed)
# Label mismatch count:  4261
# example: sed -n '1025017,1025037p' < pubmed-abstracts.conll
# ALSO CHECKED consistency of NE tags within the NE => consistent!
#############################################################################################################
# 2. cell: check concepts without beginning (on target PubMed)

import numpy as np
import matplotlib.pyplot as plt
import time
import glob

#########################
labelMismatchCnt = 0    #
NEtagLabels = []        #
#########################

# Dictionaries of total counts of occurrences of chemical/disease: 
# key=chemicalCode/diseaseCode, value=count 
# if chemical/disease is not in this dictionary then assume zero count
chemCnts = {} 
diseCnts = {}
# Dictionary of cooccurrences: key=chemicalCode+diseaseCode, value=count
cooc = {}     

TMP_chemCnts = {} # dictionaries as above, but temporary, for current sentence only
TMP_diseCnts = {}

tmpStr = '' # temporary string storing a current concept being parsed

########################################################################################
# HELPER FUNCTIONS 

# Abstract the given full concept name (c)
def abstract_concept(c):
    # Remove the following characters from (c)
    rmv_chars = " '-,/*+.!@#$%^&*()_={}[];\:<>?" 
    #rmv_chars = " " 
    c = c.translate(None, rmv_chars)
    c = c.translate(None, '"') # quotes are removed separately
    # Convert to lower case
    c = c.lower()
    return c

# End of concept check & update: update counts once a whole concept is parsed
def eoc():
    
    global NEtagLabel
    global labelMismatchCnt
    global NEtagLabels
    global LINE_NUM
    
    global tmpStr
    global TMP_diseCnts
    global TMP_chemCnts
    global cnt_matched
    global cnt_NOT_matched

    if tmpStr != '': # yes, temporary string is not empty
        # Simple approximate string matching
        ac = abstract_concept(tmpStr)
        # Is this abstracted concept in our grounding dictionary ?
        if ac in ground_dict:
            matched_MESH_concept = ground_dict[ac]
            mLabel = matched_MESH_concept[1]  # matched label = chemical / disease   
            mCode =  matched_MESH_concept[2]  # matched code of chemical / disease
            #print "YES: ", tmpStr, "<==>", matched_MESH_concept[0], "\t *** ", ac
            
            # CHECK LABEL AGREEMENT NE ~ CONCEPT
            if NEtagLabel != mLabel:
                print LINE_NUM, "Label mismatch: ", NEtagLabel, NEtagLabels[-1], mLabel
                labelMismatchCnt += 1
                if NEtagLabel != NEtagLabels[-1]: # just a sanity check, never happened
                    print LINE_NUM, NEtagLabel, NEtagLabels
                
            # CHECK LABEL AGREEMENT WITHIN NE
            for iii in NEtagLabels[1:]:
                if iii != NEtagLabels[0]:
                    print LINE_NUM, "Label mismatch of NE items within NE:", NEtagLabels, tmpStr
            
            # UPDATE COUNTS for this concept
            if mLabel == 'Disease':
                if mCode not in TMP_diseCnts.keys():
                    TMP_diseCnts[mCode] = 1
                else:
                    TMP_diseCnts[mCode] += 1
            elif mLabel == 'Chemical':
                if mCode not in TMP_chemCnts.keys():
                    TMP_chemCnts[mCode] = 1
                else:
                    TMP_chemCnts[mCode] += 1
            else:
                raise ValueError('Unknown concept!')

            cnt_matched += 1
        else:
            #print "NO :", tmpStr
            cnt_NOT_matched += 1
        
        tmpStr = ''
        
        NEtagLabels = []
        
# End of sentence update: update total counts based on temporary counts from this sentence, once a whole sentence is parsed
def eos():
    
    global chemCnts
    global diseCnts
    global cooc
    
    for chem in TMP_chemCnts.keys():
        # Update chemical counts
        if chem not in chemCnts.keys(): 
            chemCnts[chem] = 1
        else:
            chemCnts[chem] += 1

        for dise in TMP_diseCnts.keys():
            # Update disease counts
            if dise not in diseCnts.keys():
                diseCnts[dise] = 1
            else:
                diseCnts[dise] += 1

            # Update co-occurences - minimum of 2x in total will be considered by filtering later
            k = chem + '+' + dise # construct key into dictionary of cooccurences: chemicalCode+diseaseCode, always this ordering
            if k not in cooc.keys():
                cooc[k] = 1
            else:
                cooc[k] += 1

# END OF HELPER FUNCTIONS 
########################################################################################

# Load MESH concepts: <name, type (Chemical or Disease), code>
MESH = np.loadtxt('./../Dataset/CDR_MeSH.tsv', delimiter='\t', skiprows=0, dtype=str) # <name, label, code>

# Construct the Gounding dictionary
# maps grounded/abstracted concept to list [full concept name, type (Chemical or Disease), code]
ground_dict = {}
for r in MESH:
    ac = abstract_concept(r[0])
    ground_dict[ac] = r
    
########################################################################################
########################################################################################
                    
# Iterate over PubMed abstracts and associated tags (produced by named entity recogniser)

st = time.time()
N_sentences = 0      # to count number of sentences
LINE_NUM = 0
cnt_matched = 0      # count matched concepts
cnt_NOT_matched = 0  # count not-matched concepts
cnt_cwb = 0          # count concepts without beginning tag B-...

with open('/home/janciovec/Desktop/pubmed-abstracts.conll') as f_NE:     # named entities;  301,084,933 lines, using grep -c '' pubmed-abstracts_tags
    with open('/home/janciovec/Desktop/pubmed-abstracts_tags') as f_TA:  # associated tags; 301,084,933 lines
        
        # Iterate over all lines
        while True: 
            
            LINE_NUM += 1

            # Read line - named entity
            rl = f_NE.readline()
            rlwn = rl.split('\n')[0] # read line skipping the new line character

            # End of file
            if rl == '':
                if f_TA.readline() != '':
                    raise ValueError("File with tags does not match the file with named entities!")
                # End of concept check & update
                eoc()
                # End of sentence update
                eos()
                break

            # End of sentence
            elif rlwn == '':
                if f_TA.readline() != '\n':
                    raise ValueError("File with tags does not match the file with named entities!")
                # End of concept check & update
                eoc()
                # End of sentence update
                eos()
                # Reset temporary counters for next sentence
                TMP_chemCnts = {}
                TMP_diseCnts = {}
                N_sentences += 1

            # Beginning or within sentence
            else:
                # Read associated tag
                tag = f_TA.readline().split('\n')[0]
                # Named entity - first item at the line
                NE = rlwn.split('\t')[0]
                
                # Beginning of concept
                if tag[0] == 'B': 

                    # End of concept check & update - since there could be a concept ending right now
                    eoc()
                    # Start new concept
                    tmpStr = NE
                    NEtagLabel = tag[2:]
                    NEtagLabels.append( NEtagLabel )
                    
                # Continuation of the concept name
                elif tag[0] == 'I': 
                    
                    if tmpStr == '': # Concept without beginning: start new one from this string
                        if TMP_chemCnts != {}:
                            #print LINE_NUM, "Concept without beginning! NOT BEGIN OF SENTENCE"
                            cnt_cwb += 1
                            
#                     else:
#                         # from NE item to NE item, check if consecutive NE item tags agree
#                         if NEtagLabel != tag[2:]:
#                             print "NE item tag change within NE:", LINE_NUM, tmpStr
                    
                    tmpStr = tmpStr + NE # concatenate words without a space between them
        
                    NEtagLabel = tag[2:]
                    NEtagLabels.append( NEtagLabel )
                    
                elif tag[0] == 'O':
                    # End of concept check & update
                    eoc()
                    
                    NEtagLabel = tag[0]
#                     NEtagLabels.append( NEtagLabel )
                else:
                    raise ValueError("Unknown tag!")
                    
            if LINE_NUM % 30000000 == 0:
                print 100.*LINE_NUM/301084933, " % processed; time so far: ", time.time()-st, " s"

print "Time taken ...", time.time()-st, " s"

print "Total # concepts: ", cnt_NOT_matched + cnt_matched
print "Matched concepts: ", cnt_matched

print "Concepts without beginning tag (B-...): ", cnt_cwb

print "Total # sentences: ", N_sentences

print "Label mismatch count: ", labelMismatchCnt

##############################################################################################################
# Total time: 1568.43784904 seconds = 26.14 minutes (with printing), 20.42 min
# Total # concepts:   9,105,005
# Matched concepts:   5,940,715
# Concepts without beginning tag (B-...):  452
# Total # sentences: 10,573,978

# To give examples of concepts witout beginning
# sed -n '1750573,1750577p' < pubmed-abstracts_tags
# sed -n '1750573,1750577p' < pubmed-abstracts.conll
# Out:
# 53462 Label mismatch:  Disease Disease Chemical
# 113231 Label mismatch:  Chemical Chemical Disease
# 211427 Label mismatch:  Chemical Chemical Disease
# 211539 Label mismatch:  Chemical Chemical Disease
# 211561 Label mismatch:  Chemical Chemical Disease
# 224549 Label mismatch:  Chemical Chemical Disease
# 332022 Label mismatch:  Chemical Chemical Disease
# 590789 Label mismatch:  Chemical Chemical Disease
# 622167 Label mismatch:  Chemical Chemical Disease
# 1025027 Label mismatch:  Chemical Chemical Disease
# 1026812 Label mismatch:  Chemical Chemical Disease
# 1027011 Label mismatch:  Chemical Chemical Disease
# 1091093 Label mismatch:  Chemical Chemical Disease
# 1091625 Label mismatch:  Chemical Chemical Disease
# 1091666 Label mismatch:  Chemical Chemical Disease
# 1091676 Label mismatch:  Chemical Chemical Disease
# 1091697 Label mismatch:  Chemical Chemical Disease
# 1091917 Label mismatch:  Chemical Chemical Disease
# 1266307 Label mismatch:  Chemical Chemical Disease
# 1357835 Label mismatch:  Chemical Chemical Disease
# 1412386 Label mismatch:  Chemical Chemical Disease
# 1562934 Label mismatch:  Chemical Chemical Disease
# 1638034 Label mismatch:  Chemical Chemical Disease
# 1638067 Label mismatch:  Chemical Chemical Disease
# 1638110 Label mismatch:  Chemical Chemical Disease
# 1638221 Label mismatch:  Chemical Chemical Disease
# 1716379 Label mismatch:  Chemical Chemical Disease
# 1853676 Label mismatch:  Disease Disease Chemical
# 1853703 Label mismatch:  Disease Disease Chemical
# 1853748 Label mismatch:  Disease Disease Chemical
# 2148985 Label mismatch:  Chemical Chemical Disease
# 2489719 Label mismatch:  Chemical Chemical Disease
# 2489749 Label mismatch:  Chemical Chemical Disease
# 2489768 Label mismatch:  Chemical Chemical Disease
# 2879170 Label mismatch:  Chemical Chemical Disease
# 2879222 Label mismatch:  Chemical Chemical Disease
# 2879240 Label mismatch:  Chemical Chemical Disease
# 2879363 Label mismatch:  Chemical Chemical Disease
# 3018015 Label mismatch:  Chemical Chemical Disease
# 26867237 Label mismatch:  Chemical Chemical Disease
# 26868955 Label mismatch:  Chemical Chemical Disease
# 26959512 Label mismatch:  Chemical Chemical Disease
# 27066942 Label mismatch:  Chemical Chemical Disease
# 27227051 Label mismatch:  Chemical Chemical Disease
# 27517610 Label mismatch:  Chemical Chemical Disease
# 27700870 Label mismatch:  Disease Disease Chemical
# 27814001 Label mismatch:  Chemical Chemical Disease
# 27920364 Label mismatch:  Chemical Chemical Disease
# 27989142 Label mismatch:  Chemical Chemical Disease
# 28063954 Label mismatch:  Chemical Chemical Disease
# 28245159 Label mismatch:  Disease Disease Chemical
# 28328796 Label mismatch:  Chemical Chemical Disease
# 28328834 Label mismatch:  Chemical Chemical Disease
# 28328868 Label mismatch:  Chemical Chemical Disease
# 28328934 Label mismatch:  Chemical Chemical Disease
# 28328984 Label mismatch:  Chemical Chemical Disease
# 28329146 Label mismatch:  Chemical Chemical Disease
# 28329180 Label mismatch:  Chemical Chemical Disease
# 28337180 Label mismatch:  Chemical Chemical Disease
# 28404954 Label mismatch:  Chemical Chemical Disease
# 28496133 Label mismatch:  Chemical Chemical Disease
# 28496180 Label mismatch:  Chemical Chemical Disease
# 28496219 Label mismatch:  Chemical Chemical Disease
# 28496244 Label mismatch:  Chemical Chemical Disease
# 28557615 Label mismatch:  Chemical Chemical Disease
# 28557861 Label mismatch:  Chemical Chemical Disease
# 28631683 Label mismatch:  Chemical Chemical Disease
# 28631710 Label mismatch:  Chemical Chemical Disease
# 28631813 Label mismatch:  Chemical Chemical Disease
# 28709202 Label mismatch:  Chemical Chemical Disease
# 28709295 Label mismatch:  Chemical Chemical Disease
# 28761793 Label mismatch:  Chemical Chemical Disease
# 28761825 Label mismatch:  Chemical Chemical Disease
# 28761856 Label mismatch:  Chemical Chemical Disease
# 28761864 Label mismatch:  Chemical Chemical Disease
# 28761872 Label mismatch:  Chemical Chemical Disease
# 28761947 Label mismatch:  Chemical Chemical Disease
# 28873519 Label mismatch:  Chemical Chemical Disease
# 28996851 Label mismatch:  Chemical Chemical Disease
# 29035451 Label mismatch:  Chemical Chemical Disease
# 29035514 Label mismatch:  Chemical Chemical Disease
# 29205477 Label mismatch:  Chemical Chemical Disease
# 29368878 Label mismatch:  Chemical Chemical Disease
# 29432029 Label mismatch:  Chemical Chemical Disease
# 29463281 Label mismatch:  Chemical Chemical Disease
# 29463333 Label mismatch:  Chemical Chemical Disease
# 29463437 Label mismatch:  Chemical Chemical Disease
# 29850356 Label mismatch:  Disease Disease Chemical
# 29925842 Label mismatch:  Chemical Chemical Disease
# 29955176 Label mismatch:  Chemical Chemical Disease
# 29955265 Label mismatch:  Chemical Chemical Disease
# 29955361 Label mismatch:  Chemical Chemical Disease
# 29982778 Label mismatch:  Chemical Chemical Disease
# 9.96396588201  % processed; time so far:  79.6995539665  s
# 30000112 Label mismatch:  Chemical Chemical Disease
# 30187328 Label mismatch:  Chemical Chemical Disease
# 30289742 Label mismatch:  Chemical Chemical Disease
# 30289797 Label mismatch:  Chemical Chemical Disease
# 45016767 Label mismatch:  Chemical Chemical Disease
# 45204747 Label mismatch:  Chemical Chemical Disease
# 45204809 Label mismatch:  Chemical Chemical Disease
# 45221479 Label mismatch:  Chemical Chemical Disease
# 45244428 Label mismatch:  Chemical Chemical Disease
# 45280671 Label mismatch:  Chemical Chemical Disease
# 45307113 Label mismatch:  Chemical Chemical Disease
# 45307169 Label mismatch:  Chemical Chemical Disease
# 45307412 Label mismatch:  Chemical Chemical Disease
# 45402496 Label mismatch:  Chemical Chemical Disease
# 45404055 Label mismatch:  Chemical Chemical Disease
# 45404082 Label mismatch:  Chemical Chemical Disease
# 45505289 Label mismatch:  Chemical Chemical Disease
# 45544323 Label mismatch:  Chemical Chemical Disease
# 45575273 Label mismatch:  Chemical Chemical Disease
# 45575426 Label mismatch:  Chemical Chemical Disease
# 45575586 Label mismatch:  Chemical Chemical Disease
# 45583027 Label mismatch:  Chemical Chemical Disease
# 45710157 Label mismatch:  Chemical Chemical Disease
# 45858341 Label mismatch:  Chemical Chemical Disease
# 45870931 Label mismatch:  Chemical Chemical Disease
# 45909122 Label mismatch:  Chemical Chemical Disease
# 45911694 Label mismatch:  Chemical Chemical Disease
# 45933624 Label mismatch:  Disease Disease Chemical
# 45941738 Label mismatch:  Chemical Chemical Disease
# 45941841 Label mismatch:  Chemical Chemical Disease
# 45941914 Label mismatch:  Chemical Chemical Disease
# 45942017 Label mismatch:  Chemical Chemical Disease
# 45942052 Label mismatch:  Chemical Chemical Disease
# 45947928 Label mismatch:  Chemical Chemical Disease
# 45967403 Label mismatch:  Chemical Chemical Disease
# 46041870 Label mismatch:  Chemical Chemical Disease
# 46070560 Label mismatch:  Chemical Chemical Disease
# 46135792 Label mismatch:  Disease Disease Chemical
# 46160713 Label mismatch:  Chemical Chemical Disease
# 46160723 Label mismatch:  Chemical Chemical Disease
# 46160733 Label mismatch:  Chemical Chemical Disease
# 46344532 Label mismatch:  Chemical Chemical Disease
# 46357964 Label mismatch:  Chemical Chemical Disease
# 46371849 Label mismatch:  Chemical Chemical Disease
# 46457950 Label mismatch:  Chemical Chemical Disease
# 46935695 Label mismatch:  Disease Disease Chemical
# 46959914 Label mismatch:  Chemical Chemical Disease
# 46959950 Label mismatch:  Chemical Chemical Disease
# 46960060 Label mismatch:  Chemical Chemical Disease
# 46968296 Label mismatch:  Chemical Chemical Disease
# 47052375 Label mismatch:  Chemical Chemical Disease
# 47052429 Label mismatch:  Chemical Chemical Disease
# 47073872 Label mismatch:  Chemical Chemical Disease
# 47075289 Label mismatch:  Chemical Chemical Disease
# 47142066 Label mismatch:  Chemical Chemical Disease
# 47142094 Label mismatch:  Chemical Chemical Disease
# 47381484 Label mismatch:  Chemical Chemical Disease
# 47381688 Label mismatch:  Chemical Chemical Disease
# 47455611 Label mismatch:  Chemical Chemical Disease
# 47459356 Label mismatch:  Chemical Chemical Disease
# 47459367 Label mismatch:  Chemical Chemical Disease
# 47536886 Label mismatch:  Chemical Chemical Disease
# 47578817 Label mismatch:  Disease Disease Chemical
# 62695694 Label mismatch:  Chemical Chemical Disease
# 63196656 Label mismatch:  Chemical Chemical Disease
# 63234845 Label mismatch:  Chemical Chemical Disease
# 63235678 Label mismatch:  Disease Disease Chemical
# 63340050 Label mismatch:  Chemical Chemical Disease
# 63341251 Label mismatch:  Chemical Chemical Disease
# 63407939 Label mismatch:  Chemical Chemical Disease
# 63533001 Label mismatch:  Chemical Chemical Disease
# 63533100 Label mismatch:  Chemical Chemical Disease
# 63533137 Label mismatch:  Chemical Chemical Disease
# 63576078 Label mismatch:  Chemical Chemical Disease
# 63576263 Label mismatch:  Chemical Chemical Disease
# 63677772 Label mismatch:  Chemical Chemical Disease
# 63677821 Label mismatch:  Chemical Chemical Disease
# 63677890 Label mismatch:  Chemical Chemical Disease
# 63677949 Label mismatch:  Chemical Chemical Disease
# 63775122 Label mismatch:  Chemical Chemical Disease
# 63849587 Label mismatch:  Chemical Chemical Disease
# 63938074 Label mismatch:  Chemical Chemical Disease
# 64046878 Label mismatch:  Chemical Chemical Disease
# 64152442 Label mismatch:  Chemical Chemical Disease
# 64152631 Label mismatch:  Chemical Chemical Disease
# 64152658 Label mismatch:  Chemical Chemical Disease
# 64152675 Label mismatch:  Chemical Chemical Disease
# 64152747 Label mismatch:  Chemical Chemical Disease
# 64152792 Label mismatch:  Chemical Chemical Disease
# 64330416 Label mismatch:  Chemical Chemical Disease
# 64340998 Label mismatch:  Chemical Chemical Disease
# 64341017 Label mismatch:  Chemical Chemical Disease
# 64341242 Label mismatch:  Chemical Chemical Disease
# 64341261 Label mismatch:  Chemical Chemical Disease
# 64398125 Label mismatch:  Chemical Chemical Disease
# 64424437 Label mismatch:  Chemical Chemical Disease
# 64589559 Label mismatch:  Chemical Chemical Disease
# 64817051 Label mismatch:  Chemical Chemical Disease
# 64984368 Label mismatch:  Chemical Chemical Disease
# 64984419 Label mismatch:  Chemical Chemical Disease
# 65034620 Label mismatch:  Chemical Chemical Disease
# 65110762 Label mismatch:  Chemical Chemical Disease
# 65110784 Label mismatch:  Chemical Chemical Disease
# 65110876 Label mismatch:  Chemical Chemical Disease
# 65110890 Label mismatch:  Chemical Chemical Disease
# 65111033 Label mismatch:  Chemical Chemical Disease
# 65179875 Label mismatch:  Chemical Chemical Disease
# 65179904 Label mismatch:  Chemical Chemical Disease
# 65179965 Label mismatch:  Chemical Chemical Disease
# 65180033 Label mismatch:  Chemical Chemical Disease
# 65333829 Label mismatch:  Chemical Chemical Disease
# 65467904 Label mismatch:  Chemical Chemical Disease
# 65579763 Label mismatch:  Chemical Chemical Disease
# 65600227 Label mismatch:  Chemical Chemical Disease
# 65619154 Label mismatch:  Chemical Chemical Disease
# 65660440 Label mismatch:  Chemical Chemical Disease
# 65763617 Label mismatch:  Chemical Chemical Disease
# 65780004 Label mismatch:  Chemical Chemical Disease
# 66012445 Label mismatch:  Disease Disease Chemical
# ...
# 280184152 Label mismatch:  Chemical Chemical Disease
# 280516334 Label mismatch:  Chemical Chemical Disease
# 280524764 Label mismatch:  Chemical Chemical Disease
# Matched concepts:  5940715
# Concepts without beginning tag (B-...):  5
# Total # sentences:  10573978
# Label mismatch count:  4261

# %%
#############################################################################################################
# Check concepts without beginning (on target PubMed)
# #concepts without beginning tag (B-...) = 5 if COUNTED ONLY IF THEY DO NOT APPEAR AT THE BEGINNING OF SENTENCE
# otherwise: 452 is the total #concepts without beginning tag
#############################################################################################################

import numpy as np
import matplotlib.pyplot as plt
import time
import glob

# Dictionaries of total counts of occurrences of chemical/disease: 
# key=chemicalCode/diseaseCode, value=count 
# if chemical/disease is not in this dictionary then assume zero count
chemCnts = {} 
diseCnts = {}
# Dictionary of cooccurrences: key=chemicalCode+diseaseCode, value=count
cooc = {}     

TMP_chemCnts = {} # dictionaries as above, but temporary, for current sentence only
TMP_diseCnts = {}

tmpStr = '' # temporary string storing a current concept being parsed

########################################################################################
# HELPER FUNCTIONS 

# Abstract the given full concept name (c)
def abstract_concept(c):
    # Remove the following characters from (c)
    rmv_chars = " '-,/*+.!@#$%^&*()_={}[];\:<>?" 
    #rmv_chars = " " 
    c = c.translate(None, rmv_chars)
    c = c.translate(None, '"') # quotes are removed separately
    # Convert to lower case
    c = c.lower()
    return c

# End of concept check & update: update counts once a whole concept is parsed
def eoc():
    
    global tmpStr
    global TMP_diseCnts
    global TMP_chemCnts
    global cnt_matched
    global cnt_NOT_matched

    if tmpStr != '': # yes, temporary string is not empty
        # Simple approximate string matching
        ac = abstract_concept(tmpStr)
        # Is this abstracted concept in our grounding dictionary ?
        if ac in ground_dict:
            matched_MESH_concept = ground_dict[ac]
            mLabel = matched_MESH_concept[1]  # matched label = chemical / disease   
            mCode =  matched_MESH_concept[2]  # matched code of chemical / disease
            #print "YES: ", tmpStr, "<==>", matched_MESH_concept[0], "\t *** ", ac
            
            # UPDATE COUNTS for this concept
            if mLabel == 'Disease':
                if mCode not in TMP_diseCnts.keys():
                    TMP_diseCnts[mCode] = 1
                else:
                    TMP_diseCnts[mCode] += 1
            elif mLabel == 'Chemical':
                if mCode not in TMP_chemCnts.keys():
                    TMP_chemCnts[mCode] = 1
                else:
                    TMP_chemCnts[mCode] += 1
            else:
                raise ValueError('Unknown concept!')

            cnt_matched += 1
        else:
            #print "NO :", tmpStr
            cnt_NOT_matched += 1
        
        tmpStr = ''
        
# End of sentence update: update total counts based on temporary counts from this sentence, once a whole sentence is parsed
def eos():
    
    global chemCnts
    global diseCnts
    global cooc
    
    for chem in TMP_chemCnts.keys():
        # Update chemical counts
        if chem not in chemCnts.keys(): 
            chemCnts[chem] = 1
        else:
            chemCnts[chem] += 1

        for dise in TMP_diseCnts.keys():
            # Update disease counts
            if dise not in diseCnts.keys():
                diseCnts[dise] = 1
            else:
                diseCnts[dise] += 1

            # Update co-occurences - minimum of 2x in total will be considered by filtering later
            k = chem + '+' + dise # construct key into dictionary of cooccurences: chemicalCode+diseaseCode, always this ordering
            if k not in cooc.keys():
                cooc[k] = 1
            else:
                cooc[k] += 1

# END OF HELPER FUNCTIONS 
########################################################################################

# Load MESH concepts: <name, type (Chemical or Disease), code>
MESH = np.loadtxt('./../Dataset/CDR_MeSH.tsv', delimiter='\t', skiprows=0, dtype=str) # <name, label, code>

# Construct the Gounding dictionary
# maps grounded/abstracted concept to list [full concept name, type (Chemical or Disease), code]
ground_dict = {}
for r in MESH:
    ac = abstract_concept(r[0])
    ground_dict[ac] = r
    
########################################################################################
########################################################################################
                    
# Iterate over PubMed abstracts and associated tags (produced by named entity recogniser)

st = time.time()
N_sentences = 0      # to count number of sentences
LINE_NUM = 0
cnt_matched = 0      # count matched concepts
cnt_NOT_matched = 0  # count not-matched concepts
cnt_cwb = 0          # count concepts without beginning tag B-...

with open('/home/janciovec/Desktop/pubmed-abstracts.conll') as f_NE:     # named entities;  301,084,933 lines, using grep -c '' pubmed-abstracts_tags
    with open('/home/janciovec/Desktop/pubmed-abstracts_tags') as f_TA:  # associated tags; 301,084,933 lines
        
        # Iterate over all lines
        while True: 
            
            LINE_NUM += 1

            # Read line - named entity
            rl = f_NE.readline()
            rlwn = rl.split('\n')[0] # read line skipping the new line character

            # End of file
            if rl == '':
                if f_TA.readline() != '':
                    raise ValueError("File with tags does not match the file with named entities!")
                # End of concept check & update
                eoc()
                # End of sentence update
                eos()
                break

            # End of sentence
            elif rlwn == '':
                if f_TA.readline() != '\n':
                    raise ValueError("File with tags does not match the file with named entities!")
                # End of concept check & update
                eoc()
                # End of sentence update
                eos()
                # Reset temporary counters for next sentence
                TMP_chemCnts = {}
                TMP_diseCnts = {}
                N_sentences += 1

            # Beginning or within sentence
            else:
                # Read associated tag
                tag = f_TA.readline().split('\n')[0]
                # Named entity - first item at the line
                NE = rlwn.split('\t')[0]
                
                # Beginning of concept
                if tag[0] == 'B': 
                    # End of concept check & update - since there could be a concept ending right now
                    eoc()
                    # Start new concept
                    tmpStr = NE
                    
                # Continuation of the concept name
                elif tag[0] == 'I': 
        
                    if tmpStr == '': # Concept without beginning: start new one from this string
#                         if TMP_chemCnts != {}:
#                             print LINE_NUM, "Concept without beginning! NOT BEGIN OF SENTENCE"
#                             cnt_cwb += 1
                        print LINE_NUM, "Concept without beginning! ALL CASES", tag
                        cnt_cwb += 1
                    
                    tmpStr = tmpStr + NE # concatenate words without a space between them
                    
                elif tag[0] == 'O':
                    # End of concept check & update
                    eoc()
                else:
                    raise ValueError("Unknown tag!")
                    
            if LINE_NUM % 30000000 == 0:
                print 100.*LINE_NUM/301084933, " % processed; time so far: ", time.time()-st, " s"

print "Time taken ...", time.time()-st, " s"

print "Total # concepts: ", cnt_NOT_matched + cnt_matched
print "Matched concepts: ", cnt_matched

print "Concepts without beginning tag (B-...): ", cnt_cwb

print "Total # sentences: ", N_sentences

##############################################################################################################
# Total time: 1568.43784904 seconds = 26.14 minutes (with printing), 20.42 min
# Total # concepts:   9,105,005
# Matched concepts:   5,940,715
# Concepts without beginning tag (B-...):  452
# Total # sentences: 10,573,978

# To give examples of concepts witout beginning
# sed -n '1750573,1750577p' < pubmed-abstracts_tags
# sed -n '1750573,1750577p' < pubmed-abstracts.conll
# Out:
# 1750575 Concept without beginning! ALL CASES I-Disease
# 2788688 Concept without beginning! ALL CASES I-Chemical
# 3387645 Concept without beginning! ALL CASES I-Disease
# 3701988 Concept without beginning! ALL CASES I-Chemical
# 4262071 Concept without beginning! ALL CASES I-Disease
# 4430739 Concept without beginning! ALL CASES I-Disease
# 5522210 Concept without beginning! ALL CASES I-Disease
# 6175482 Concept without beginning! ALL CASES I-Chemical
# 6175655 Concept without beginning! ALL CASES I-Chemical
# 7790449 Concept without beginning! ALL CASES I-Disease
# 7965579 Concept without beginning! ALL CASES I-Chemical
# 8317729 Concept without beginning! ALL CASES I-Disease
# 9115904 Concept without beginning! ALL CASES I-Disease
# 9323695 Concept without beginning! ALL CASES I-Chemical
# 10325323 Concept without beginning! ALL CASES I-Chemical
# 10604145 Concept without beginning! ALL CASES I-Chemical
# 10752818 Concept without beginning! ALL CASES I-Chemical
# 11628326 Concept without beginning! ALL CASES I-Chemical
# 12072635 Concept without beginning! ALL CASES I-Disease
# 14946930 Concept without beginning! ALL CASES I-Disease
# 15644633 Concept without beginning! ALL CASES I-Disease
# 15918772 Concept without beginning! ALL CASES I-Disease
# 16107006 Concept without beginning! ALL CASES I-Chemical
# 16225038 Concept without beginning! ALL CASES I-Disease
# 16565696 Concept without beginning! ALL CASES I-Chemical
# 17053299 Concept without beginning! ALL CASES I-Chemical
# 17623190 Concept without beginning! ALL CASES I-Chemical
# 18159327 Concept without beginning! ALL CASES I-Disease
# 20542611 Concept without beginning! ALL CASES I-Chemical
# 20774808 Concept without beginning! ALL CASES I-Chemical
# 23578316 Concept without beginning! ALL CASES I-Disease
# 24092475 Concept without beginning! ALL CASES I-Chemical
# 24860795 Concept without beginning! ALL CASES I-Chemical
# 25816973 Concept without beginning! ALL CASES I-Chemical
# 26204977 Concept without beginning! ALL CASES I-Disease
# 27688042 Concept without beginning! ALL CASES I-Disease
# 29271376 Concept without beginning! ALL CASES I-Chemical
# 9.96396588201  % processed; time so far:  71.9512710571  s
# 30257750 Concept without beginning! ALL CASES I-Disease
# 30516579 Concept without beginning! ALL CASES I-Disease
# 30815675 Concept without beginning! ALL CASES I-Disease
# 31865373 Concept without beginning! ALL CASES I-Chemical
# 34137537 Concept without beginning! ALL CASES I-Disease
# 34721208 Concept without beginning! ALL CASES I-Chemical
# 34939143 Concept without beginning! ALL CASES I-Chemical
# 35460877 Concept without beginning! ALL CASES I-Disease
# 36222497 Concept without beginning! ALL CASES I-Disease
# 36522119 Concept without beginning! ALL CASES I-Chemical
# 36628484 Concept without beginning! ALL CASES I-Chemical
# 37349269 Concept without beginning! ALL CASES I-Chemical
# 37395444 Concept without beginning! ALL CASES I-Chemical
# 37563810 Concept without beginning! ALL CASES I-Chemical
# 37711855 Concept without beginning! ALL CASES I-Disease
# 39036751 Concept without beginning! ALL CASES I-Chemical
# 40719498 Concept without beginning! ALL CASES I-Disease
# 41199354 Concept without beginning! ALL CASES I-Disease
# 41648969 Concept without beginning! ALL CASES I-Disease
# 42197748 Concept without beginning! ALL CASES I-Chemical
# 42214532 Concept without beginning! ALL CASES I-Disease
# 42597712 Concept without beginning! ALL CASES I-Chemical
# 43388852 Concept without beginning! ALL CASES I-Disease
# 45054413 Concept without beginning! ALL CASES I-Chemical
# 45121744 Concept without beginning! ALL CASES I-Chemical
# 47284466 Concept without beginning! ALL CASES I-Disease
# 49791374 Concept without beginning! ALL CASES I-Chemical
# 50252215 Concept without beginning! ALL CASES I-Chemical
# 51356139 Concept without beginning! ALL CASES I-Disease
# 51844176 Concept without beginning! ALL CASES I-Chemical
# 51844221 Concept without beginning! ALL CASES I-Chemical
# 53330280 Concept without beginning! ALL CASES I-Chemical
# 54161488 Concept without beginning! ALL CASES I-Chemical
# 54189059 Concept without beginning! ALL CASES I-Chemical
# 55912829 Concept without beginning! ALL CASES I-Chemical
# 55992277 Concept without beginning! ALL CASES I-Chemical
# 57029514 Concept without beginning! ALL CASES I-Chemical
# 57371660 Concept without beginning! ALL CASES I-Chemical
# 58259968 Concept without beginning! ALL CASES I-Disease
# 58283163 Concept without beginning! ALL CASES I-Chemical
# 58675017 Concept without beginning! ALL CASES I-Disease
# 58983088 Concept without beginning! ALL CASES I-Chemical
# 59220116 Concept without beginning! ALL CASES I-Disease
# 19.927931764  % processed; time so far:  161.75008297  s
# 61862243 Concept without beginning! ALL CASES I-Chemical
# 62235739 Concept without beginning! ALL CASES I-Disease
# 62656518 Concept without beginning! ALL CASES I-Disease
# 62765318 Concept without beginning! ALL CASES I-Chemical
# 63592124 Concept without beginning! ALL CASES I-Disease
# 67706022 Concept without beginning! ALL CASES I-Chemical
# 67871564 Concept without beginning! ALL CASES I-Chemical
# 68080058 Concept without beginning! ALL CASES I-Chemical
# 68388366 Concept without beginning! ALL CASES I-Disease
# 68526254 Concept without beginning! ALL CASES I-Chemical
# 69564775 Concept without beginning! ALL CASES I-Chemical
# 69605930 Concept without beginning! ALL CASES I-Chemical
# 69618100 Concept without beginning! ALL CASES I-Chemical
# 69959490 Concept without beginning! ALL CASES I-Chemical
# 69960690 Concept without beginning! ALL CASES I-Disease
# 69973164 Concept without beginning! ALL CASES I-Disease
# 70516150 Concept without beginning! ALL CASES I-Disease
# 70617202 Concept without beginning! ALL CASES I-Disease
# 73914820 Concept without beginning! ALL CASES I-Disease
# 74012149 Concept without beginning! ALL CASES I-Disease
# 74033397 Concept without beginning! ALL CASES I-Chemical
# 74937544 Concept without beginning! ALL CASES I-Disease
# 75245254 Concept without beginning! ALL CASES I-Disease
# 75476837 Concept without beginning! ALL CASES I-Chemical
# 77426646 Concept without beginning! ALL CASES I-Chemical
# 78719427 Concept without beginning! ALL CASES I-Chemical
# 79040724 Concept without beginning! ALL CASES I-Disease
# 79382094 Concept without beginning! ALL CASES I-Disease
# 80349565 Concept without beginning! ALL CASES I-Disease
# 80486032 Concept without beginning! ALL CASES I-Disease
# 80531027 Concept without beginning! ALL CASES I-Chemical
# 80569206 Concept without beginning! ALL CASES I-Chemical
# 80592611 Concept without beginning! ALL CASES I-Chemical
# 81102713 Concept without beginning! ALL CASES I-Chemical
# 81629682 Concept without beginning! ALL CASES I-Chemical
# 82171517 Concept without beginning! ALL CASES I-Chemical
# 82891230 Concept without beginning! ALL CASES I-Disease
# 83887485 Concept without beginning! ALL CASES I-Disease
# 84275918 Concept without beginning! ALL CASES I-Chemical
# 84523554 Concept without beginning! ALL CASES I-Chemical
# 85217042 Concept without beginning! ALL CASES I-Chemical
# 85342800 Concept without beginning! ALL CASES I-Chemical
# 85600916 Concept without beginning! ALL CASES I-Chemical
# 85827933 Concept without beginning! ALL CASES I-Chemical
# 86787139 Concept without beginning! ALL CASES I-Disease
# 88397349 Concept without beginning! ALL CASES I-Chemical
# 89252815 Concept without beginning! ALL CASES I-Chemical
# 89404782 Concept without beginning! ALL CASES I-Disease
# 29.891897646  % processed; time so far:  264.83509016  s
# 90975661 Concept without beginning! ALL CASES I-Disease
# 93883374 Concept without beginning! ALL CASES I-Chemical
# 96104379 Concept without beginning! ALL CASES I-Disease
# 96677623 Concept without beginning! ALL CASES I-Disease
# 97321168 Concept without beginning! ALL CASES I-Chemical
# 99852146 Concept without beginning! ALL CASES I-Disease
# 100032735 Concept without beginning! ALL CASES I-Chemical
# 100053655 Concept without beginning! ALL CASES I-Chemical
# 100053693 Concept without beginning! ALL CASES I-Chemical
# 100923172 Concept without beginning! ALL CASES I-Chemical
# 101381272 Concept without beginning! ALL CASES I-Disease
# 101604973 Concept without beginning! ALL CASES I-Chemical
# 101878471 Concept without beginning! ALL CASES I-Chemical
# 102146139 Concept without beginning! ALL CASES I-Disease
# 102794818 Concept without beginning! ALL CASES I-Chemical
# 102807207 Concept without beginning! ALL CASES I-Chemical
# 103729368 Concept without beginning! ALL CASES I-Disease
# 104777377 Concept without beginning! ALL CASES I-Chemical
# 105331266 Concept without beginning! ALL CASES I-Chemical
# 105648098 Concept without beginning! ALL CASES I-Disease
# 107101231 Concept without beginning! ALL CASES I-Disease
# 107300485 Concept without beginning! ALL CASES I-Disease
# 107472315 Concept without beginning! ALL CASES I-Chemical
# 107713280 Concept without beginning! ALL CASES I-Chemical
# 107913119 Concept without beginning! ALL CASES I-Chemical
# 107913156 Concept without beginning! ALL CASES I-Chemical
# 109648628 Concept without beginning! ALL CASES I-Disease
# 109648678 Concept without beginning! ALL CASES I-Disease
# 110369449 Concept without beginning! ALL CASES I-Chemical
# 110808432 Concept without beginning! ALL CASES I-Chemical
# 111142531 Concept without beginning! ALL CASES I-Chemical
# 111961888 Concept without beginning! ALL CASES I-Disease
# 113158550 Concept without beginning! ALL CASES I-Chemical
# 113526272 Concept without beginning! ALL CASES I-Chemical
# 113526305 Concept without beginning! ALL CASES I-Chemical
# 115632155 Concept without beginning! ALL CASES I-Chemical
# 116018874 Concept without beginning! ALL CASES I-Disease
# 116519605 Concept without beginning! ALL CASES I-Disease
# 116682764 Concept without beginning! ALL CASES I-Disease
# 117356244 Concept without beginning! ALL CASES I-Chemical
# 117421908 Concept without beginning! ALL CASES I-Disease
# 117827450 Concept without beginning! ALL CASES I-Disease
# 119583634 Concept without beginning! ALL CASES I-Disease
# 39.855863528  % processed; time so far:  385.711770058  s
# 121529193 Concept without beginning! ALL CASES I-Chemical
# 122702658 Concept without beginning! ALL CASES I-Disease
# 122703819 Concept without beginning! ALL CASES I-Disease
# 123346831 Concept without beginning! ALL CASES I-Chemical
# 123406693 Concept without beginning! ALL CASES I-Chemical
# 123590290 Concept without beginning! ALL CASES I-Disease
# 123864810 Concept without beginning! ALL CASES I-Disease
# 124479393 Concept without beginning! ALL CASES I-Disease
# 125039932 Concept without beginning! ALL CASES I-Chemical
# 125832158 Concept without beginning! ALL CASES I-Disease
# 126245715 Concept without beginning! ALL CASES I-Disease
# 127232949 Concept without beginning! ALL CASES I-Disease
# 127308630 Concept without beginning! ALL CASES I-Chemical
# 127872605 Concept without beginning! ALL CASES I-Disease
# 129627208 Concept without beginning! ALL CASES I-Disease
# 130213883 Concept without beginning! ALL CASES I-Chemical
# 130748555 Concept without beginning! ALL CASES I-Chemical
# 131050962 Concept without beginning! ALL CASES I-Disease
# 132081849 Concept without beginning! ALL CASES I-Disease
# 133272137 Concept without beginning! ALL CASES I-Disease
# 133362046 Concept without beginning! ALL CASES I-Chemical
# 134973384 Concept without beginning! ALL CASES I-Disease
# 135131827 Concept without beginning! ALL CASES I-Chemical
# 136546870 Concept without beginning! ALL CASES I-Chemical
# 136678779 Concept without beginning! ALL CASES I-Chemical
# 136678853 Concept without beginning! ALL CASES I-Disease
# 136723658 Concept without beginning! ALL CASES I-Disease
# 137882636 Concept without beginning! ALL CASES I-Disease
# 139352741 Concept without beginning! ALL CASES I-Disease
# 140159892 Concept without beginning! ALL CASES I-Disease
# 140504758 Concept without beginning! ALL CASES I-Disease
# 140973531 Concept without beginning! ALL CASES I-Chemical
# 141763641 Concept without beginning! ALL CASES I-Disease
# 142133841 Concept without beginning! ALL CASES I-Chemical
# 142383850 Concept without beginning! ALL CASES I-Chemical
# 143355563 Concept without beginning! ALL CASES I-Chemical
# 143355648 Concept without beginning! ALL CASES I-Chemical
# 143897225 Concept without beginning! ALL CASES I-Disease
# 144245769 Concept without beginning! ALL CASES I-Chemical
# 145605804 Concept without beginning! ALL CASES I-Disease
# 147296914 Concept without beginning! ALL CASES I-Disease
# 147728079 Concept without beginning! ALL CASES I-Chemical
# 147994191 Concept without beginning! ALL CASES I-Disease
# 148031823 Concept without beginning! ALL CASES I-Disease
# 148752564 Concept without beginning! ALL CASES I-Disease
# 149243994 Concept without beginning! ALL CASES I-Chemical
# 49.8198294101  % processed; time so far:  511.349673033  s
# 150370618 Concept without beginning! ALL CASES I-Chemical
# 150499343 Concept without beginning! ALL CASES I-Chemical
# 150886972 Concept without beginning! ALL CASES I-Disease
# 151142021 Concept without beginning! ALL CASES I-Disease
# 151187087 Concept without beginning! ALL CASES I-Disease
# 151505034 Concept without beginning! ALL CASES I-Chemical
# 151929345 Concept without beginning! ALL CASES I-Chemical
# 153034654 Concept without beginning! ALL CASES I-Chemical
# 153648851 Concept without beginning! ALL CASES I-Chemical
# 153705342 Concept without beginning! ALL CASES I-Chemical
# 154373340 Concept without beginning! ALL CASES I-Chemical
# 154762826 Concept without beginning! ALL CASES I-Chemical
# 155341105 Concept without beginning! ALL CASES I-Chemical
# 155341210 Concept without beginning! ALL CASES I-Chemical
# 155408863 Concept without beginning! ALL CASES I-Disease
# 155417138 Concept without beginning! ALL CASES I-Chemical
# 155417173 Concept without beginning! ALL CASES I-Chemical
# 155982759 Concept without beginning! ALL CASES I-Disease
# 156634865 Concept without beginning! ALL CASES I-Disease
# 156930585 Concept without beginning! ALL CASES I-Disease
# 157061255 Concept without beginning! ALL CASES I-Disease
# 158561873 Concept without beginning! ALL CASES I-Disease
# 159397853 Concept without beginning! ALL CASES I-Chemical
# 159761865 Concept without beginning! ALL CASES I-Chemical
# 159842127 Concept without beginning! ALL CASES I-Chemical
# 162701164 Concept without beginning! ALL CASES I-Chemical
# 163175541 Concept without beginning! ALL CASES I-Disease
# 163423632 Concept without beginning! ALL CASES I-Chemical
# 163460706 Concept without beginning! ALL CASES I-Disease
# 163694937 Concept without beginning! ALL CASES I-Disease
# 164228595 Concept without beginning! ALL CASES I-Disease
# 165038478 Concept without beginning! ALL CASES I-Chemical
# 165038632 Concept without beginning! ALL CASES I-Chemical
# 165267229 Concept without beginning! ALL CASES I-Chemical
# 165778150 Concept without beginning! ALL CASES I-Disease
# 166492077 Concept without beginning! ALL CASES I-Chemical
# 168511888 Concept without beginning! ALL CASES I-Disease
# 168874593 Concept without beginning! ALL CASES I-Disease
# 169066566 Concept without beginning! ALL CASES I-Chemical
# 169845238 Concept without beginning! ALL CASES I-Disease
# 170644277 Concept without beginning! ALL CASES I-Disease
# 170644318 Concept without beginning! ALL CASES I-Disease
# 170644369 Concept without beginning! ALL CASES I-Disease
# 171204293 Concept without beginning! ALL CASES I-Disease
# 172937344 Concept without beginning! ALL CASES I-Chemical
# 172937376 Concept without beginning! ALL CASES I-Chemical
# 173502025 Concept without beginning! ALL CASES I-Disease
# 173587752 Concept without beginning! ALL CASES I-Chemical
# 173670813 Concept without beginning! ALL CASES I-Disease
# 174142324 Concept without beginning! ALL CASES I-Chemical
# 176384683 Concept without beginning! ALL CASES I-Chemical
# 176839581 Concept without beginning! ALL CASES I-Chemical
# 177343573 Concept without beginning! ALL CASES I-Disease
# 177895755 Concept without beginning! ALL CASES I-Chemical
# 178096109 Concept without beginning! ALL CASES I-Disease
# 179017379 Concept without beginning! ALL CASES I-Disease
# 179415823 Concept without beginning! ALL CASES I-Disease
# 59.7837952921  % processed; time so far:  638.73694706  s
# 180480475 Concept without beginning! ALL CASES I-Disease
# 182239441 Concept without beginning! ALL CASES I-Disease
# 184117323 Concept without beginning! ALL CASES I-Disease
# 184491324 Concept without beginning! ALL CASES I-Disease
# 185605266 Concept without beginning! ALL CASES I-Disease
# 186180114 Concept without beginning! ALL CASES I-Chemical
# 186700175 Concept without beginning! ALL CASES I-Chemical
# 187027923 Concept without beginning! ALL CASES I-Disease
# 187517233 Concept without beginning! ALL CASES I-Chemical
# 187594382 Concept without beginning! ALL CASES I-Chemical
# 187688064 Concept without beginning! ALL CASES I-Disease
# 189014163 Concept without beginning! ALL CASES I-Disease
# 189515511 Concept without beginning! ALL CASES I-Chemical
# 189609348 Concept without beginning! ALL CASES I-Disease
# 190004631 Concept without beginning! ALL CASES I-Disease
# 190887521 Concept without beginning! ALL CASES I-Chemical
# 192175944 Concept without beginning! ALL CASES I-Disease
# 192303686 Concept without beginning! ALL CASES I-Disease
# 192348547 Concept without beginning! ALL CASES I-Chemical
# 192348585 Concept without beginning! ALL CASES I-Chemical
# 193415809 Concept without beginning! ALL CASES I-Chemical
# 193753127 Concept without beginning! ALL CASES I-Disease
# 194037951 Concept without beginning! ALL CASES I-Disease
# 194399353 Concept without beginning! ALL CASES I-Chemical
# 195231539 Concept without beginning! ALL CASES I-Disease
# 195332457 Concept without beginning! ALL CASES I-Disease
# 195365153 Concept without beginning! ALL CASES I-Disease
# 196321951 Concept without beginning! ALL CASES I-Disease
# 197840560 Concept without beginning! ALL CASES I-Disease
# 199204010 Concept without beginning! ALL CASES I-Disease
# 200676796 Concept without beginning! ALL CASES I-Disease
# 201724523 Concept without beginning! ALL CASES I-Chemical
# 201875893 Concept without beginning! ALL CASES I-Chemical
# 202584097 Concept without beginning! ALL CASES I-Disease
# 202712984 Concept without beginning! ALL CASES I-Disease
# 203264886 Concept without beginning! ALL CASES I-Chemical
# 204201252 Concept without beginning! ALL CASES I-Disease
# 204646578 Concept without beginning! ALL CASES I-Disease
# 206329632 Concept without beginning! ALL CASES I-Disease
# 206533731 Concept without beginning! ALL CASES I-Disease
# 207991617 Concept without beginning! ALL CASES I-Disease
# 208494540 Concept without beginning! ALL CASES I-Disease
# 208509993 Concept without beginning! ALL CASES I-Disease
# 208724489 Concept without beginning! ALL CASES I-Chemical
# 69.7477611741  % processed; time so far:  771.145531178  s
# 210736746 Concept without beginning! ALL CASES I-Disease
# 211514738 Concept without beginning! ALL CASES I-Chemical
# 211514863 Concept without beginning! ALL CASES I-Chemical
# 211992460 Concept without beginning! ALL CASES I-Disease
# 212654193 Concept without beginning! ALL CASES I-Disease
# 213468428 Concept without beginning! ALL CASES I-Disease
# 213536293 Concept without beginning! ALL CASES I-Chemical
# 215588031 Concept without beginning! ALL CASES I-Chemical
# 216757235 Concept without beginning! ALL CASES I-Disease
# 216809322 Concept without beginning! ALL CASES I-Disease
# 217304900 Concept without beginning! ALL CASES I-Disease
# 218286354 Concept without beginning! ALL CASES I-Chemical
# 218286374 Concept without beginning! ALL CASES I-Chemical
# 220239306 Concept without beginning! ALL CASES I-Chemical
# 223394331 Concept without beginning! ALL CASES I-Disease
# 223766452 Concept without beginning! ALL CASES I-Chemical
# 227326332 Concept without beginning! ALL CASES I-Disease
# 227423780 Concept without beginning! ALL CASES I-Disease
# 229496482 Concept without beginning! ALL CASES I-Chemical
# 230134147 Concept without beginning! ALL CASES I-Disease
# 230532758 Concept without beginning! ALL CASES I-Disease
# 231632405 Concept without beginning! ALL CASES I-Chemical
# 231791522 Concept without beginning! ALL CASES I-Chemical
# 232622663 Concept without beginning! ALL CASES I-Disease
# 233638023 Concept without beginning! ALL CASES I-Disease
# 233687888 Concept without beginning! ALL CASES I-Chemical
# 234116452 Concept without beginning! ALL CASES I-Disease
# 234249014 Concept without beginning! ALL CASES I-Chemical
# 236437962 Concept without beginning! ALL CASES I-Disease
# 237837229 Concept without beginning! ALL CASES I-Disease
# 239900138 Concept without beginning! ALL CASES I-Chemical
# 239900326 Concept without beginning! ALL CASES I-Chemical
# 239918428 Concept without beginning! ALL CASES I-Disease
# 79.7117270561  % processed; time so far:  904.02354908  s
# 240547372 Concept without beginning! ALL CASES I-Disease
# 240631591 Concept without beginning! ALL CASES I-Disease
# 240754575 Concept without beginning! ALL CASES I-Disease
# 241099787 Concept without beginning! ALL CASES I-Disease
# 243342669 Concept without beginning! ALL CASES I-Disease
# 243466196 Concept without beginning! ALL CASES I-Disease
# 243842491 Concept without beginning! ALL CASES I-Chemical
# 244040533 Concept without beginning! ALL CASES I-Chemical
# 244040582 Concept without beginning! ALL CASES I-Chemical
# 244914331 Concept without beginning! ALL CASES I-Chemical
# 245917216 Concept without beginning! ALL CASES I-Disease
# 246778667 Concept without beginning! ALL CASES I-Chemical
# 248965333 Concept without beginning! ALL CASES I-Disease
# 250285174 Concept without beginning! ALL CASES I-Chemical
# 250514401 Concept without beginning! ALL CASES I-Chemical
# 251903665 Concept without beginning! ALL CASES I-Disease
# 252813142 Concept without beginning! ALL CASES I-Disease
# 253327002 Concept without beginning! ALL CASES I-Chemical
# 253398982 Concept without beginning! ALL CASES I-Disease
# 253607094 Concept without beginning! ALL CASES I-Chemical
# 254543261 Concept without beginning! ALL CASES I-Disease
# 255287064 Concept without beginning! ALL CASES I-Chemical
# 255287429 Concept without beginning! ALL CASES I-Chemical
# 255340388 Concept without beginning! ALL CASES I-Chemical
# 255569168 Concept without beginning! ALL CASES I-Disease
# 255626867 Concept without beginning! ALL CASES I-Chemical
# 255693135 Concept without beginning! ALL CASES I-Disease
# 255807098 Concept without beginning! ALL CASES I-Chemical
# 256253188 Concept without beginning! ALL CASES I-Chemical
# 256591945 Concept without beginning! ALL CASES I-Chemical
# 256948728 Concept without beginning! ALL CASES I-Disease
# 257675803 Concept without beginning! ALL CASES I-Chemical
# 257810244 Concept without beginning! ALL CASES I-Disease
# 258853122 Concept without beginning! ALL CASES I-Disease
# 260689997 Concept without beginning! ALL CASES I-Chemical
# 261029527 Concept without beginning! ALL CASES I-Disease
# 261627223 Concept without beginning! ALL CASES I-Chemical
# 262325279 Concept without beginning! ALL CASES I-Disease
# 262538495 Concept without beginning! ALL CASES I-Chemical
# 263302311 Concept without beginning! ALL CASES I-Chemical
# 263899621 Concept without beginning! ALL CASES I-Disease
# 264759140 Concept without beginning! ALL CASES I-Disease
# 267545852 Concept without beginning! ALL CASES I-Disease
# 267893626 Concept without beginning! ALL CASES I-Chemical
# 268353347 Concept without beginning! ALL CASES I-Disease
# 89.6756929381  % processed; time so far:  1077.99882102  s
# 270068379 Concept without beginning! ALL CASES I-Chemical
# 270129939 Concept without beginning! ALL CASES I-Disease
# 270619510 Concept without beginning! ALL CASES I-Chemical
# 271873752 Concept without beginning! ALL CASES I-Disease
# 273104428 Concept without beginning! ALL CASES I-Chemical
# 273104500 Concept without beginning! ALL CASES I-Chemical
# 273652058 Concept without beginning! ALL CASES I-Chemical
# 274092330 Concept without beginning! ALL CASES I-Disease
# 276123077 Concept without beginning! ALL CASES I-Chemical
# 276324748 Concept without beginning! ALL CASES I-Chemical
# 277312880 Concept without beginning! ALL CASES I-Chemical
# 278116974 Concept without beginning! ALL CASES I-Disease
# 279151159 Concept without beginning! ALL CASES I-Disease
# 279798089 Concept without beginning! ALL CASES I-Disease
# 279798103 Concept without beginning! ALL CASES I-Disease
# 280497916 Concept without beginning! ALL CASES I-Chemical
# 280783921 Concept without beginning! ALL CASES I-Chemical
# 281347155 Concept without beginning! ALL CASES I-Disease
# 281899554 Concept without beginning! ALL CASES I-Disease
# 283105824 Concept without beginning! ALL CASES I-Disease
# 283762707 Concept without beginning! ALL CASES I-Chemical
# 284048992 Concept without beginning! ALL CASES I-Chemical
# 284135641 Concept without beginning! ALL CASES I-Disease
# 284145085 Concept without beginning! ALL CASES I-Disease
# 284517970 Concept without beginning! ALL CASES I-Chemical
# 284588111 Concept without beginning! ALL CASES I-Chemical
# 284736929 Concept without beginning! ALL CASES I-Disease
# 285586130 Concept without beginning! ALL CASES I-Chemical
# 286071526 Concept without beginning! ALL CASES I-Disease
# 286196961 Concept without beginning! ALL CASES I-Chemical
# 286668365 Concept without beginning! ALL CASES I-Chemical
# 287261024 Concept without beginning! ALL CASES I-Disease
# 287473215 Concept without beginning! ALL CASES I-Chemical
# 287493237 Concept without beginning! ALL CASES I-Chemical
# 288367511 Concept without beginning! ALL CASES I-Disease
# 289733315 Concept without beginning! ALL CASES I-Chemical
# 290087129 Concept without beginning! ALL CASES I-Disease
# 291171784 Concept without beginning! ALL CASES I-Chemical
# 291600334 Concept without beginning! ALL CASES I-Chemical
# 292310442 Concept without beginning! ALL CASES I-Disease
# 293915053 Concept without beginning! ALL CASES I-Disease
# 293943886 Concept without beginning! ALL CASES I-Chemical
# 294582644 Concept without beginning! ALL CASES I-Chemical
# 294869662 Concept without beginning! ALL CASES I-Chemical
# 295358007 Concept without beginning! ALL CASES I-Chemical
# 296147656 Concept without beginning! ALL CASES I-Chemical
# 296286463 Concept without beginning! ALL CASES I-Disease
# 296328336 Concept without beginning! ALL CASES I-Chemical
# 297100570 Concept without beginning! ALL CASES I-Disease
# 297392187 Concept without beginning! ALL CASES I-Chemical
# 298064154 Concept without beginning! ALL CASES I-Chemical
# 299268702 Concept without beginning! ALL CASES I-Chemical
# 299289353 Concept without beginning! ALL CASES I-Chemical
# 299399175 Concept without beginning! ALL CASES I-Disease
# 99.6396588201  % processed; time so far:  1252.74683499  s
# 300159762 Concept without beginning! ALL CASES I-Chemical
# 300227491 Concept without beginning! ALL CASES I-Chemical
# Time taken ... 1259.48541999  s
# Total # concepts:  9105005
# Matched concepts:  5940715
# Concepts without beginning tag (B-...):  452
# Total # sentences:  10573978
