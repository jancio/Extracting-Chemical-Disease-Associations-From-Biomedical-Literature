# %%
################################################################################################
# Extracting chemical-disease associations from the biological literature
# R214: Main Practical
# Jan Ondras (jo356), Trinity College
################################################################################################
# Grounding of named entities to MESH concepts 
# using Simple approximate string matching (SASM)
################################################################################################

import numpy as np
import matplotlib.pyplot as plt
import time
import glob

# Set which partition to use for evaluation
dataset_type = 'train' # train, devel, or test
dataset_type = 'devel'
dataset_type = 'test'

# Load tagged named entities, preserving sentence segmentation
NE = []
ii = 0
with open('./bmip-2018-master/BC5-CDR/conll/' + dataset_type + '.tsv') as f:
    rl = f.readline()
    while rl != '':
        ii += 1
        rlwn = rl.split('\n')[0] # read line skipping the new line character
        
        # End of sentence
        if rlwn == '':
            NE.append([])
            #print ii, "EOS" # end of sentence
        # Beginning or within sentence
        else:           
            NE.append(rlwn.split('\t'))
            #print ii, NE[-1]
        rl = f.readline()

# Load MESH concepts: <name, type (Chemical or Disease), code>
MESH = np.loadtxt('./../Dataset/CDR_MeSH.tsv', delimiter='\t', skiprows=0, dtype=str)

# %%
# Print sample MeSH entries
print MESH[0:300]
# Out:
# [['11-deoxycortisol' 'Chemical' 'D003350']
#  ['1,1-dichloro-2,2,2-trifluoroethane' 'Chemical' 'C067411']
#  ['1-[2-(3,4-dichlorophenyl)ethyl]-4-methylpiperazine' 'Chemical' 'C093337']
#  ['1,2-dimethylhydrazine' 'Chemical' 'D019813']
#  ['1,2-DMH' 'Chemical' 'D019813']
#  ['1-(2-methoxyphenyl)-4-[4-(2-phthalimido)butyl]piperazine' 'Chemical'
#   'C058895']
#  ['1,3-bis-(2-chloroethyl)-1-nitrosourea' 'Chemical' 'D002330']
#  ['17beta-estradiol' 'Chemical' 'D004958']
#  ['17beta-Estradiol' 'Chemical' 'D004958']
#  ['1-bromo-1-chloro-2,2,2-trifluoroethane' 'Chemical' 'D006221']
#  ['1-chloro-1,2,2,2-tetrafluoroethane' 'Chemical' 'C072959']
#  ['2-acetylaminofluorene' 'Chemical' 'D015073']
#  ['2-chloroprocaine-CE' 'Chemical' 'C004616']
#  ['2-methoxy-4-amino-5-chlorobenzoic acid 2-(diethylamino)ethyl ester'
#   'Chemical' 'C072790']
#  ['2-methyl-6-(phenylethynyl)pyridine' 'Chemical' 'C121465']
#  ['2PAM' 'Chemical' 'D011220']
#  ['3,4-dihydroxyphenylacetic acid' 'Chemical' 'D015102']
#  ['3,4-methylenedioxymethamphetamine' 'Chemical' 'D018817']
#  ['3alpha-hydroxy-3beta-methyl-5alpha-pregnan-20-one' 'Chemical' 'C105051']
#  ['3alpha-hydroxy-5alpha-pregnan-20-one' 'Chemical' 'D011280']
#  ['3alpha-hydroxy-5beta-pregnan-20-one' 'Chemical' 'D011280']
#  ['3 alpha-tropyl 2-(p-bromophenyl)propionate' 'Chemical' 'C087567']
#  ['3alpha-tropyl 2-(p-bromophenyl)propionate' 'Chemical' 'C087567']
#  ['3-aminopropyl-diethoxy-methyl-phosphinic acid' 'Chemical' 'C066430']
#  ['3-benzenesulfonyl-7-(4-methyl-piperazin-1-yl)1H-indole' 'Chemical'
#   'C507242']
#  ['[3H]-5-azadeoxycytidine' 'Chemical' 'C014347']
#  ['[3H]-l-arginine' 'Chemical' 'D001120']
#  ['[3H]-L-arginine' 'Chemical' 'D001120']
#  ['3H-TBOB' 'Chemical' 'C046308']
#  ['3-hydroxybutyrate' 'Chemical' 'D020155']
#  ['3MA' 'Chemical' 'C025946']
#  ['3-mercaptopropionic acid' 'Chemical' 'D015097']
#  ['3-methyladenine' 'Chemical' 'C025946']
#  [ '3SR,4aRS,6SR,8aRS-6-[phosphonomethyl]decahydr oisoquinoline-3- carboxylic acid'
#   'Chemical' 'C070935']
#  ["4'-0-tetrahydropyranyladriamycin" 'Chemical' 'C027260']
#  ['4-DAMP' 'Chemical' 'C042375']
#  ['4-diphenylacetoxy-N-methylpiperidine' 'Chemical' 'C042375']
#  [ '5 - [2- ( 4- ( 3 - fluorobenzylidene) piperidin-1-yl) ethyl] - 4 -(4-fluorophenyl) thiazole-2-carboxamide'
#   'Chemical' 'C121249']
#  [ '5,5-dimethyl-3-(3-fluorophenyl)-4-(4-methylsulphonyl) phenyl-2(5H)-furanon'
#   'Chemical' 'C106876']
#  ['5-azacytidine' 'Chemical' 'D001374']
#  ['5-AzC' 'Chemical' 'D001374']
#  ['5-fluorouracil' 'Chemical' 'D005472']
#  ['5-FU' 'Chemical' 'D005472']
#  ['5-HT' 'Chemical' 'D012701']
#  ['5-HTP' 'Chemical' 'D006916']
#  ['5-hydroxytriptamine' 'Chemical' 'D012701']
#  ['5-hydroxytryptamin1A' 'Chemical' 'D012701']
#  ['5-hydroxytryptamine4' 'Chemical' 'D012701']
#  ['5-hydroxytryptamine' 'Chemical' 'D012701']
#  ['5-hydroxytryptophan' 'Chemical' 'D006916']
#  ['6-hydroxydopamine' 'Chemical' 'D016627']
#  ['6-OHDA' 'Chemical' 'D016627']
#  [ '8-[(4-amino-l-methylbutyl)amino]- 5-(l-hexyloxy)-6-methoxy-4-methylquinoline'
#   'Chemical' 'C068820']
#  ['8-aminoquinoline' 'Chemical' 'C080436']
#  [ '9-[[2-methoxy-4-[(methylsulphonyl)amino]phenyl]amino] -N,5-dimethyl- 4-acridinecarboxamide'
#   'Chemical' 'C042315']
#  ['99mTc-glucarate' 'Chemical' 'C067171']
#  ['AAP' 'Chemical' 'D000082']
#  ['AAPH' 'Chemical' 'C046728']
#  ['abdominal pain' 'Disease' 'D015746']
#  [ 'abnormal audiograms with deficits mostly in the high frequency range of 4,000 to 8,000 Hz'
#   'Disease' 'D006316']
#  ['Abnormal involuntary movements' 'Disease' 'D004409']
#  ['abnormalities of liver function' 'Disease' 'D056486']
#  ['abnormal liver function' 'Disease' 'D056486']
#  ['abnormal movements' 'Disease' 'D004409']
#  ['Abnormal movements' 'Disease' 'D004409']
#  ['absence epilepsy' 'Disease' 'D004832']
#  ['absence seizure' 'Disease' 'D004832']
#  ['absence seizures' 'Disease' 'D004832']
#  ['ACC-9089' 'Chemical' 'C047847']
#  ['ACEi' 'Chemical' 'D000806']
#  ['ACE inhibitor' 'Chemical' 'D000806']
#  ['ACE inhibitors' 'Chemical' 'D000806']
#  ['acetaldehyde' 'Chemical' 'D000079']
#  ['acetaminophen' 'Chemical' 'D000082']
#  ['Acetaminophen' 'Chemical' 'D000082']
#  ['acetazolamide' 'Chemical' 'D000086']
#  ['Acetazolamide' 'Chemical' 'D000086']
#  ['aceto-acetate' 'Chemical' 'C016635']
#  ['acetylcholine' 'Chemical' 'D000109']
#  ['acetylsalicylic acid' 'Chemical' 'D001241']
#  ['Acetylsalicylic acid' 'Chemical' 'D001241']
#  ['ACh' 'Chemical' 'D000109']
#  ['acidosis' 'Disease' 'D000138']
#  ['acitretin' 'Chemical' 'D017255']
#  ['acne' 'Disease' 'D000152']
#  ['acriflavine' 'Chemical' 'D000167']
#  ['acrodermatitis enteropathica' 'Disease' 'C538178']
#  ['acromegalic' 'Disease' 'D000172']
#  ['acromegaly' 'Disease' 'D000172']
#  ['Acromegaly' 'Disease' 'D000172']
#  ['Actomycin-D' 'Chemical' 'D003609']
#  ['acute alcohol intoxication' 'Disease' 'D000435']
#  ['acute cardiovascular failure' 'Disease' 'D002318']
#  ['acute cholecystitis' 'Disease' 'D041881']
#  ['acute coronary insufficiency' 'Disease' 'D054058']
#  ['acute hepatitis' 'Disease' 'D017114']
#  ['acute hepatitis-like illness' 'Disease' 'D056486']
#  ['acute hepatitis-like syndrome' 'Disease' 'D056486']
#  ['acute leukemia' 'Disease' 'D015470']
#  ['acute liver failure' 'Disease' 'D017114']
#  ['Acute liver failure' 'Disease' 'D017114']
#  ['acute lymphoblastic leucemia' 'Disease' 'D054198']
#  ['acute lymphoblastic leukemia' 'Disease' 'D054198']
#  ['acute myocardial infarction' 'Disease' 'D009203']
#  ['acute nonlymphocytic leukemia' 'Disease' 'D015470']
#  ['acute pain' 'Disease' 'D059787']
#  ['Acute psychosis' 'Disease' 'D011605']
#  ['acute renal dysfunction' 'Disease' 'D058186']
#  ['acute renal failure and hepatic failure' 'Disease' 'D058186']
#  ['acute renal failure' 'Disease' 'D058186']
#  ['acute stroke' 'Disease' 'D020521']
#  ['acute T-lymphocytic leukemia' 'Disease' 'D054218']
#  ['acute tubular necrosis' 'Disease' 'D007683']
#  ['a decrease in MAP, HR, SV, and CO' 'Disease' 'D007022']
#  ['adefovir' 'Chemical' 'C053001']
#  ['adenocarcinoma' 'Disease' 'D000230']
#  ['adenocarcinoma of the liver' 'Disease' 'D000230']
#  ['adenohypophyseal tumors' 'Disease' 'D010911']
#  ['adenoma' 'Disease' 'D000236']
#  ['adenosine' 'Chemical' 'D000241']
#  ['ADHD' 'Disease' 'D001289']
#  ['ADP' 'Chemical' 'D000244']
#  ['ADR' 'Chemical' 'D004317']
#  ['adrenaline' 'Chemical' 'D004837']
#  ['adriamycin' 'Chemical' 'D004317']
#  ['Adriamycin' 'Chemical' 'D004317']
#  ['Adriamycinol' 'Chemical' 'C010013']
#  ['adriamycinone' 'Chemical' 'C010012']
#  ['adverse drug reaction' 'Disease' 'D064420']
#  ['adverse drug reactions' 'Disease' 'D064420']
#  ['adverse effect on the proximal eighth nerve' 'Disease' 'D000160']
#  ['aggression' 'Disease' 'D001523']
#  ['aggressive behavior' 'Disease' 'D010554']
#  ['aggressiveness' 'Disease' 'D010554']
#  ['agitation' 'Disease' 'D011595']
#  ['agoraphobia' 'Disease' 'D000379']
#  ['agranulocytosis' 'Disease' 'D000380']
#  ['Agranulocytosis' 'Disease' 'D000380']
#  ['AHF' 'Disease' 'D006478']
#  ['AIDS' 'Disease' 'D000163']
#  ['airway obstruction' 'Disease' 'D000402']
#  ['akathisia' 'Disease' 'D017109']
#  ['Akathisia' 'Disease' 'D017109']
#  ['akinetic' 'Disease' 'D018476']
#  ['alanine' 'Chemical' 'D000409']
#  ['albuminuria' 'Disease' 'D000419']
#  ['alcohol' 'Chemical' 'D000431']
#  ['ALCOHOL' 'Chemical' 'D000431']
#  ['alcoholic extract of the berries of hawthorn' 'Chemical' 'C007145']
#  ['aldehyde' 'Chemical' 'D000079']
#  ['aldosterone' 'Chemical' 'D000450']
#  ['alendronate' 'Chemical' 'D019386']
#  ['alendronate sodium' 'Chemical' 'D019386']
#  ['ALF' 'Disease' 'D017114']
#  ['alfentanil' 'Chemical' 'D015760']
#  ['alkylating agents' 'Chemical' 'D000477']
#  ['ALL' 'Disease' 'D054198']
#  ['allergic' 'Disease' 'D004342']
#  ['allergic reaction' 'Disease' 'D004342']
#  ['Allergic reaction' 'Disease' 'D004342']
#  ['allergic reactions' 'Disease' 'D004342']
#  ['allergy' 'Disease' 'D004342']
#  ['allopregnanolone' 'Chemical' 'D011280']
#  ['Allopregnanolone' 'Chemical' 'D011280']
#  ['allopurinol' 'Chemical' 'D000493']
#  ['Allopurinol' 'Chemical' 'D000493']
#  ['alopecia' 'Disease' 'D000505']
#  ['Alopecia' 'Disease' 'D000505']
#  ['a loss of visual acuity' 'Disease' 'D014786']
#  ['alpha,beta-meATP' 'Chemical' 'C002630']
#  ["alpha,beta-methylene adenosine-5'-triphosphate" 'Chemical' 'C002630']
#  ['alpha-lipoic acid' 'Chemical' 'D008063']
#  ['Alpha-lipoic acid' 'Chemical' 'D008063']
#  ['alpha-methyldopa' 'Chemical' 'D008750']
#  ['alpha-methyltyrosine' 'Chemical' 'D019805']
#  ['alpha-TAc' 'Chemical' 'D024502']
#  ['alpha-T' 'Chemical' 'D024502']
#  ['alpha-tocopherol acetate' 'Chemical' 'D024502']
#  ['alpha-tocopherol' 'Chemical' 'D024502']
#  ['alprazolam' 'Chemical' 'D000525']
#  ['Alprazolam' 'Chemical' 'D000525']
#  ["Alzheimer's disease" 'Disease' 'D000544']
#  ['amantadine' 'Chemical' 'D000547']
#  ['Amantadine' 'Chemical' 'D000547']
#  ['amantadine hydrochloride' 'Chemical' 'D000547']
#  ['AmB' 'Chemical' 'D000666']
#  ['AMCA' 'Chemical' 'D014148']
#  ['amenorrhea' 'Disease' 'D000568']
#  ['AMI' 'Chemical' 'D000638']
#  ['amifostine' 'Chemical' 'D004999']
#  ['Amifostine' 'Chemical' 'D004999']
#  ['amikacin' 'Chemical' 'D000583']
#  ['amiloride' 'Chemical' 'D000584']
#  ['Amiloride' 'Chemical' 'D000584']
#  ['amine' 'Chemical' 'D000588']
#  ['amines' 'Chemical' 'D000588']
#  ['amino acid' 'Chemical' 'D000596']
#  ['aminoaciduria' 'Disease' 'D000608']
#  ['aminoglycoside' 'Chemical' 'D000617']
#  ['Aminoglycoside' 'Chemical' 'D000617']
#  ['aminoglycosides' 'Chemical' 'D000617']
#  ['aminophylline' 'Chemical' 'D000628']
#  ['amiodarone' 'Chemical' 'D000638']
#  ['Amiodarone' 'Chemical' 'D000638']
#  ['amitriptyline' 'Chemical' 'D000639']
#  ['amnesia' 'Disease' 'D000647']
#  ['Amnesia' 'Disease' 'D000647']
#  ['amnesic' 'Disease' 'D000647']
#  ['amoxicillin' 'Chemical' 'D000658']
#  ['amoxicillin-clavulanic acid' 'Chemical' 'D019980']
#  ['AMP' 'Chemical' 'D000667']
#  ['amphetamine abuse' 'Disease' 'D019969']
#  ['amphetamine' 'Chemical' 'D000661']
#  ['amphotericin B' 'Chemical' 'D000666']
#  ['amphotericin' 'Chemical' 'D000666']
#  ['ampicillin' 'Chemical' 'D000667']
#  ['amsacrine' 'Chemical' 'D000677']
#  ['amyloid beta peptide(1-42)' 'Chemical' 'C544092']
#  ['anaphylaxis' 'Disease' 'D000707']
#  ['Anaphylaxis' 'Disease' 'D000707']
#  ['anemia' 'Disease' 'D000740']
#  ['anencephaly' 'Disease' 'D000757']
#  ['Anencephaly' 'Disease' 'D000757']
#  ['aneurysmal rupture' 'Disease' 'D017542']
#  ['aneurysm' 'Disease' 'D000783']
#  ['aneurysms' 'Disease' 'D000783']
#  ['Angina' 'Disease' 'D000787']
#  ['angina pectoris' 'Disease' 'D000787']
#  ['angioedema' 'Disease' 'D000799']
#  ['Angioedema' 'Disease' 'D000799']
#  ['angioneurotic edema' 'Disease' 'D000799']
#  ['angiopathy' 'Disease' 'D001018']
#  ['Angiosarcoma' 'Disease' 'D006394']
#  ['Angiosarcoma of the liver' 'Disease' 'D006394']
#  ['angiotensin' 'Chemical' 'D000809']
#  ['Angiotensin' 'Chemical' 'D000809']
#  ['angiotensin-converting enzyme (ACE) inhibitor' 'Chemical' 'D000806']
#  ['angiotensin converting enzyme (ACE) inhibitors' 'Chemical' 'D000806']
#  ['angiotensin II' 'Chemical' 'D000804']
#  ['angiotensin-releasing blocker' 'Chemical' 'D057911']
#  ['Angiotension II' 'Chemical' 'D000804']
#  ['anophthalmia' 'Disease' 'D000853']
#  ['anorexia' 'Disease' 'D000855']
#  ['anthracycline' 'Chemical' 'D018943']
#  ['anthracyclines' 'Chemical' 'D018943']
#  ['Anthracyclines' 'Chemical' 'D018943']
#  ['antidepressant' 'Chemical' 'D000928']
#  ['Antidepressant' 'Chemical' 'D000928']
#  ['antidepressants' 'Chemical' 'D000928']
#  ['antiphospholipid syndrome' 'Disease' 'D016736']
#  ['antithymocyte globulin' 'Chemical' 'D000961']
#  ['Antithymocyte globulin' 'Chemical' 'D000961']
#  ['Antituberculosis' 'Chemical' 'D000995']
#  ['anuria' 'Disease' 'D001002']
#  ['anxiety' 'Disease' 'D001008']
#  ['anxiety neurosis' 'Disease' 'D001008']
#  ['aortic regurgitation' 'Disease' 'D001022']
#  ['Apamin' 'Chemical' 'D001030']
#  ['aplastic anaemia' 'Disease' 'D000741']
#  ['aplastic anemia' 'Disease' 'D000741']
#  ['apnea' 'Disease' 'D001049']
#  ['apnoea' 'Disease' 'D001049']
#  ['apomorphine' 'Chemical' 'D001058']
#  ['Apomorphine' 'Chemical' 'D001058']
#  ['aponidine hydrochloride' 'Chemical' 'C016986']
#  ['appetite suppressant' 'Chemical' 'D001067']
#  ['appetite suppressants' 'Chemical' 'D001067']
#  ['appetite-suppressants' 'Chemical' 'D001067']
#  ['apraclonidine' 'Chemical' 'C016986']
#  ['AraG' 'Chemical' 'C104457']
#  ['ARB' 'Chemical' 'D057911']
#  ['a reduced locomotor activity' 'Disease' 'D001523']
#  ['argatroban' 'Chemical' 'C031942']
#  ['Argentine hemorrhagic fever' 'Disease' 'D006478']
#  ['arginine vasopressin' 'Chemical' 'D001127']
#  ['aripiprazole' 'Chemical' 'C094645']
#  ['arrhythmia' 'Disease' 'D001145']
#  ['arrhythmias' 'Disease' 'D001145']
#  ['arterial hypotension' 'Disease' 'D007022']
#  ['arterial injury' 'Disease' 'D014652']
#  ['arteriopathic' 'Disease' 'D014652']
#  ['arteriovenous malformations' 'Disease' 'D001165']
#  ['artery calcification' 'Disease' 'D061205']
#  ['arthralgias' 'Disease' 'D018771']
#  ['arthritis' 'Disease' 'D001168']
#  ['arthrogryposis' 'Disease' 'D001176']
#  ['ASA' 'Chemical' 'D001241']
#  ['ascites' 'Disease' 'D001201']
#  ['asenapine' 'Chemical' 'C522667']
#  ['Asenapine' 'Chemical' 'C522667']
#  ['aspartate' 'Chemical' 'D001224']
#  ['aspirin' 'Chemical' 'D001241']
#  ['asterixis' 'Disease' 'D020820']
#  ['astrocytomas' 'Disease' 'D001254']
#  ['asystole' 'Disease' 'D006323']
#  ['ataxia' 'Disease' 'D001259']
#  ['ataxic movements' 'Disease' 'D001259']
#  ['atazanavir' 'Chemical' 'C413408']
#  ['atherosclerosis' 'Disease' 'D050197']
#  ['Atherosclerosis' 'Disease' 'D050197']]

# %%
################################################
# ABSTRACTION FUNCTION
# Abstract the given full concept name (c)
def abstract_concept(c):
    
    # Remove the following characters from (c)
    rmv_chars = " '-,/*+.!@#$%^&*()_={}[];\:<>?"
    #rmv_chars = " " 
    c = c.translate(None, rmv_chars)
    c = c.translate(None, '"') # quotes are removed separately
    # Convert to lower case
    c = c.lower()
    return c

################################################
# Construct the Gounding dictionary: 
# maps grounded/abstracted concept to list [full concept name, type (Chemical or Disease), code]
ground_dict = {}
for r in MESH:
    ac = abstract_concept(r[0])
    ground_dict[ac] = r

# %%
################################################################################################
# Iterate over tagged concepts and find matches with MESH concepts
# 5 experiments for each set: methods E1,E2,A1,A2,A3

#######################
# on training set ---- total 9385 concepts

# 7113 matches with exact matching, concatenate words without a space between them, on training set
# 8779 matches with exact matching, concatenate words with a space between them,    on training set
# 9309 matches with approx match: remove spaces
# 9309 matches with approx match: remove spaces + to lower case ---- no improvement as the MESH dictionary already handles this
# 9309 matches with approx match: above + tried to remove all these '-,/*+.!@#$%^&*()_={}[];\:<>?" but without improvement

#######################
# on development set ---- total 9591 concepts

# 5037 matches with exact matching, concatenate words without a space between them, on training set
# 5682 matches with exact matching, concatenate words with a space between them,    on training set
# 5848 matches with approx match: remove spaces
# 6085 matches with approx match: remove spaces + to lower case ---- improvement!!! => in training set the lower and upper case concepts match the possibilities present in MESH; but this is not the case for testing set => better to convert to lower case!
# 6098 matches with approx match: all above + remove all these '-,/*+.!@#$%^&*()_={}[];\:<>?" with improvement

###################
# on testing set ---- total 9809 concepts

# 5014 matches with exact matching, concatenate words without a space between them, on training set
# 5682 matches with exact matching, concatenate words with a space between them,    on training set
# 5845 matches with approx match: remove spaces
# 6101 matches with approx match: remove spaces + to lower case ---- improvement!!! => in training set the lower and upper case concepts match the possibilities present in MESH; but this is not the case for testing set => better to convert to lower case!
# 6134 matches with approx match: all above + remove all these '-,/*+.!@#$%^&*()_={}[];\:<>?" with improvement
#        31 of the improvement caused by char -

st = time.time()
cnt_matched = 0      # count matched concepts
cnt_NOT_matched = 0  # count not-matched concepts

all_AC = set()       # to count unique matched concepts
matched_AC = set()   # to count unique matched concepts

# If the character ch is present in one of the strings a,b but not both; used to generate some examples
def check(a,b):
    ch = '(' # to print matchings with particular character
    if ch in a and ch not in b:
        return True
    if ch not in a and ch in b:
        return True
    return False

i = 0
while i < len(NE):
    
    # End of sentence
    if NE[i] == []:
        i += 1
    
    # Beginning of chemical or disease concept
    elif NE[i][5][0] == 'B': # check tag beginning
        
        tmpStr = NE[i][0] # initialise temporary string for this concept
        i += 1
        
        # Continuation of this concept name         
        while True:
            if NE[i] == []:
                break
            if NE[i][5][0] != 'I':
                break
            #tmpStr = tmpStr + ' ' + NE[i][0]      # concatenate words WITH a space between them
            tmpStr = tmpStr + NE[i][0] # concatenate words without a space between them
            i += 1
        
        # Simple approximate string matching
        ac = abstract_concept(tmpStr)
        all_AC.add( ac )
        
        # Is this abstracted concept in our grounding dictionary ?
        if ac in ground_dict:
            matched_MESH_concept = ground_dict[ac]
#             if check(tmpStr, matched_MESH_concept[0]):
#                 print tmpStr, "<==>", matched_MESH_concept[0], "\t *** ", ac
            print "YES: ", tmpStr, "<==>", matched_MESH_concept, "\t *** ", ac
            cnt_matched += 1
            matched_AC.add( ac )
        else:
            #print "NO :", tmpStr
            cnt_NOT_matched += 1
            
    # Continuation of chemical or disease concept OR "other - O"
    else:
        i += 1

print "---------------------------------------------------\nDATASET", dataset_type
        
print "Total  : ", cnt_NOT_matched + cnt_matched
print "Matched: ", cnt_matched

print "Unique concept counts:"
print "Total  : ", len(all_AC)
print "Matched: ", len(matched_AC)

print "Time taken: ", time.time() - st, "sec"
# Out:
# YES:  ventriculartachycardia <==> ['ventricular tachycardia' 'Disease' 'D017180'] 	 ***  ventriculartachycardia
# YES:  dobutamine <==> ['Dobutamine' 'Chemical' 'D004280'] 	 ***  dobutamine
# YES:  dilatedcardiomyopathy <==> ['dilated cardiomyopathy' 'Disease' 'D002311'] 	 ***  dilatedcardiomyopathy
# YES:  congestiveheartfailure <==> ['congestive heart failure' 'Disease' 'D006333'] 	 ***  congestiveheartfailure
# YES:  heartfailure <==> ['heart failure' 'Disease' 'D006333'] 	 ***  heartfailure
# YES:  dilatedcardiomyopathy <==> ['dilated cardiomyopathy' 'Disease' 'D002311'] 	 ***  dilatedcardiomyopathy
# YES:  ventriculararrhythmias <==> ['ventricular arrhythmias' 'Disease' 'D001145'] 	 ***  ventriculararrhythmias
# YES:  QTprolongation <==> ['Q-T prolongation' 'Disease' 'D008133'] 	 ***  qtprolongation
# YES:  ventriculartachycardia <==> ['ventricular tachycardia' 'Disease' 'D017180'] 	 ***  ventriculartachycardia
# YES:  dobutamine <==> ['Dobutamine' 'Chemical' 'D004280'] 	 ***  dobutamine
# YES:  ventriculartachycardia <==> ['ventricular tachycardia' 'Disease' 'D017180'] 	 ***  ventriculartachycardia
# YES:  dobutamine <==> ['Dobutamine' 'Chemical' 'D004280'] 	 ***  dobutamine
# YES:  arrhythmias <==> ['arrhythmias' 'Disease' 'D001145'] 	 ***  arrhythmias
# YES:  dyspnea <==> ['dyspnea' 'Disease' 'D004417'] 	 ***  dyspnea
# YES:  lossofconsciousness <==> ['Loss of consciousness' 'Disease' 'D014474'] 	 ***  lossofconsciousness
# YES:  pain <==> ['Pain' 'Disease' 'D010146'] 	 ***  pain
# YES:  allergy <==> ['allergy' 'Disease' 'D004342'] 	 ***  allergy
# YES:  cancer <==> ['Cancer' 'Disease' 'D009369'] 	 ***  cancer
# YES:  5-fluorouracil <==> ['5-fluorouracil' 'Chemical' 'D005472'] 	 ***  5fluorouracil
# YES:  dehydration <==> ['dehydration' 'Disease' 'D003681'] 	 ***  dehydration
# YES:  infection <==> ['infection' 'Disease' 'D007239'] 	 ***  infection
# YES:  cancer <==> ['Cancer' 'Disease' 'D009369'] 	 ***  cancer
# YES:  5-fluorouracil <==> ['5-fluorouracil' 'Chemical' 'D005472'] 	 ***  5fluorouracil
# YES:  5-FU <==> ['5-FU' 'Chemical' 'D005472'] 	 ***  5fu
# YES:  liverdisease <==> ['Liver disease' 'Disease' 'D008107'] 	 ***  liverdisease
# YES:  infection <==> ['infection' 'Disease' 'D007239'] 	 ***  infection
# YES:  dehydration <==> ['dehydration' 'Disease' 'D003681'] 	 ***  dehydration
# YES:  hyperammonemia <==> ['hyperammonemia' 'Disease' 'D022124'] 	 ***  hyperammonemia
# YES:  5-FU <==> ['5-FU' 'Chemical' 'D005472'] 	 ***  5fu
# YES:  5-FU <==> ['5-FU' 'Chemical' 'D005472'] 	 ***  5fu
# YES:  5-FU <==> ['5-FU' 'Chemical' 'D005472'] 	 ***  5fu
# YES:  quinine <==> ['quinine' 'Chemical' 'D011803'] 	 ***  quinine
# YES:  morphine <==> ['Morphine' 'Chemical' 'D009020'] 	 ***  morphine
# YES:  potassium <==> ['Potassium' 'Chemical' 'D011188'] 	 ***  potassium
# YES:  K <==> ['K' 'Chemical' 'D011188'] 	 ***  k
# YES:  quinine <==> ['quinine' 'Chemical' 'D011803'] 	 ***  quinine
# YES:  morphine <==> ['Morphine' 'Chemical' 'D009020'] 	 ***  morphine
# YES:  Quinine <==> ['quinine' 'Chemical' 'D011803'] 	 ***  quinine
# YES:  calcium <==> ['Calcium' 'Chemical' 'D002118'] 	 ***  calcium
# YES:  ATP <==> ['ATP' 'Chemical' 'D000255'] 	 ***  atp
# YES:  K <==> ['K' 'Chemical' 'D011188'] 	 ***  k
# YES:  K <==> ['K' 'Chemical' 'D011188'] 	 ***  k
# YES:  quinine <==> ['quinine' 'Chemical' 'D011803'] 	 ***  quinine
# YES:  morphine <==> ['Morphine' 'Chemical' 'D009020'] 	 ***  morphine
# YES:  K <==> ['K' 'Chemical' 'D011188'] 	 ***  k
# YES:  morphine <==> ['Morphine' 'Chemical' 'D009020'] 	 ***  morphine
# YES:  K <==> ['K' 'Chemical' 'D011188'] 	 ***  k
# YES:  morphine <==> ['Morphine' 'Chemical' 'D009020'] 	 ***  morphine
# YES:  hyperactivity <==> ['hyperactivity' 'Disease' 'D006948'] 	 ***  hyperactivity
# YES:  quinine <==> ['quinine' 'Chemical' 'D011803'] 	 ***  quinine
# YES:  K <==> ['K' 'Chemical' 'D011188'] 	 ***  k
# YES:  morphine <==> ['Morphine' 'Chemical' 'D009020'] 	 ***  morphine
# YES:  K <==> ['K' 'Chemical' 'D011188'] 	 ***  k
# YES:  morphine <==> ['Morphine' 'Chemical' 'D009020'] 	 ***  morphine
# YES:  morphine <==> ['Morphine' 'Chemical' 'D009020'] 	 ***  morphine
# YES:  hyperactivity <==> ['hyperactivity' 'Disease' 'D006948'] 	 ***  hyperactivity
# YES:  quinine <==> ['quinine' 'Chemical' 'D011803'] 	 ***  quinine
# YES:  K <==> ['K' 'Chemical' 'D011188'] 	 ***  k
# YES:  scopolamine <==> ['scopolamine' 'Chemical' 'D012601'] 	 ***  scopolamine
# YES:  hyperalgesia <==> ['hyperalgesia' 'Disease' 'D006930'] 	 ***  hyperalgesia
# YES:  impairmentoflearningandmemory <==> ['impairment of learning and memory' 'Disease' 'D003072'] 	 ***  impairmentoflearningandmemory
# YES:  scopolamine <==> ['scopolamine' 'Chemical' 'D012601'] 	 ***  scopolamine
# YES:  scopolamine <==> ['scopolamine' 'Chemical' 'D012601'] 	 ***  scopolamine
# YES:  scopolamine <==> ['scopolamine' 'Chemical' 'D012601'] 	 ***  scopolamine
# YES:  rheumatoidarthritis <==> ['rheumatoid arthritis' 'Disease' 'D001172'] 	 ***  rheumatoidarthritis
# YES:  hepatitis <==> ['Hepatitis' 'Disease' 'D056486'] 	 ***  hepatitis
# YES:  hepatitis <==> ['Hepatitis' 'Disease' 'D056486'] 	 ***  hepatitis
# YES:  hypersensitivity <==> ['Hypersensitivity' 'Disease' 'D004342'] 	 ***  hypersensitivity
# YES:  hepaticdamage <==> ['hepatic damage' 'Disease' 'D056486'] 	 ***  hepaticdamage
# YES:  aplasticanemia <==> ['aplastic anemia' 'Disease' 'D000741'] 	 ***  aplasticanemia
# YES:  aplasticanemia <==> ['aplastic anemia' 'Disease' 'D000741'] 	 ***  aplasticanemia
# YES:  necrosis <==> ['necrosis' 'Disease' 'D009336'] 	 ***  necrosis
# YES:  necrosis <==> ['necrosis' 'Disease' 'D009336'] 	 ***  necrosis
# YES:  aplasticanemia <==> ['aplastic anemia' 'Disease' 'D000741'] 	 ***  aplasticanemia
# YES:  aplasticanemia <==> ['aplastic anemia' 'Disease' 'D000741'] 	 ***  aplasticanemia
# YES:  catalepsy <==> ['Catalepsy' 'Disease' 'D002375'] 	 ***  catalepsy
# YES:  haloperidol <==> ['Haloperidol' 'Chemical' 'D006220'] 	 ***  haloperidol
# YES:  nitric-oxide <==> ['nitric oxide' 'Chemical' 'D009569'] 	 ***  nitricoxide
# YES:  haloperidol <==> ['Haloperidol' 'Chemical' 'D006220'] 	 ***  haloperidol
# YES:  catalepsy <==> ['Catalepsy' 'Disease' 'D002375'] 	 ***  catalepsy
# YES:  nitric-oxide <==> ['nitric oxide' 'Chemical' 'D009569'] 	 ***  nitricoxide
# YES:  catalepsy <==> ['Catalepsy' 'Disease' 'D002375'] 	 ***  catalepsy
# YES:  Nitricoxide <==> ['nitric oxide' 'Chemical' 'D009569'] 	 ***  nitricoxide
# YES:  NO <==> ['NO' 'Chemical' 'D009569'] 	 ***  no
# YES:  haloperidol <==> ['Haloperidol' 'Chemical' 'D006220'] 	 ***  haloperidol
# YES:  dopamine <==> ['Dopamine' 'Chemical' 'D004298'] 	 ***  dopamine
# YES:  catalepsy <==> ['Catalepsy' 'Disease' 'D002375'] 	 ***  catalepsy
# YES:  haloperidol <==> ['Haloperidol' 'Chemical' 'D006220'] 	 ***  haloperidol
# YES:  catalepsy <==> ['Catalepsy' 'Disease' 'D002375'] 	 ***  catalepsy
# YES:  haloperidol <==> ['Haloperidol' 'Chemical' 'D006220'] 	 ***  haloperidol
# YES:  Catalepsy <==> ['Catalepsy' 'Disease' 'D002375'] 	 ***  catalepsy
# YES:  haloperidol <==> ['Haloperidol' 'Chemical' 'D006220'] 	 ***  haloperidol
# YES:  catalepsy <==> ['Catalepsy' 'Disease' 'D002375'] 	 ***  catalepsy
# YES:  haloperidol <==> ['Haloperidol' 'Chemical' 'D006220'] 	 ***  haloperidol
# YES:  haloperidol <==> ['Haloperidol' 'Chemical' 'D006220'] 	 ***  haloperidol
# YES:  NO <==> ['NO' 'Chemical' 'D009569'] 	 ***  no
# YES:  coronaryarterydisease <==> ['coronary artery disease' 'Disease' 'D003324'] 	 ***  coronaryarterydisease
# YES:  dobutamine <==> ['Dobutamine' 'Chemical' 'D004280'] 	 ***  dobutamine
# YES:  coronaryarterydisease <==> ['coronary artery disease' 'Disease' 'D003324'] 	 ***  coronaryarterydisease
# YES:  dobutamine <==> ['Dobutamine' 'Chemical' 'D004280'] 	 ***  dobutamine
# YES:  ischaemia <==> ['ischaemia' 'Disease' 'D007511'] 	 ***  ischaemia
# YES:  coronaryarterydisease <==> ['coronary artery disease' 'Disease' 'D003324'] 	 ***  coronaryarterydisease
# YES:  dobutamine <==> ['Dobutamine' 'Chemical' 'D004280'] 	 ***  dobutamine
# YES:  depression <==> ['Depression' 'Disease' 'D003866'] 	 ***  depression
# YES:  dobutamine <==> ['Dobutamine' 'Chemical' 'D004280'] 	 ***  dobutamine
# YES:  dobutamine <==> ['Dobutamine' 'Chemical' 'D004280'] 	 ***  dobutamine
# YES:  coronaryarterydisease <==> ['coronary artery disease' 'Disease' 'D003324'] 	 ***  coronaryarterydisease
# YES:  dobutamine <==> ['Dobutamine' 'Chemical' 'D004280'] 	 ***  dobutamine
# YES:  ischaemia <==> ['ischaemia' 'Disease' 'D007511'] 	 ***  ischaemia
# YES:  myocardialstunning <==> ['myocardial stunning' 'Disease' 'D017682'] 	 ***  myocardialstunning
# YES:  Dobutamine <==> ['Dobutamine' 'Chemical' 'D004280'] 	 ***  dobutamine
# YES:  ischaemia <==> ['ischaemia' 'Disease' 'D007511'] 	 ***  ischaemia
# YES:  coronaryarterydisease <==> ['coronary artery disease' 'Disease' 'D003324'] 	 ***  coronaryarterydisease
# YES:  pulmonaryhypertension <==> ['Pulmonary hypertension' 'Disease' 'D006976'] 	 ***  pulmonaryhypertension
# YES:  pulmonaryhypertension <==> ['Pulmonary hypertension' 'Disease' 'D006976'] 	 ***  pulmonaryhypertension
# YES:  primarypulmonaryhypertension <==> ['Primary pulmonary hypertension' 'Disease' 'D006976'] 	 ***  primarypulmonaryhypertension
# YES:  pulmonaryhypertension <==> ['Pulmonary hypertension' 'Disease' 'D006976'] 	 ***  pulmonaryhypertension
# YES:  pulmonaryhypertension <==> ['Pulmonary hypertension' 'Disease' 'D006976'] 	 ***  pulmonaryhypertension
# YES:  pulmonaryhypertension <==> ['Pulmonary hypertension' 'Disease' 'D006976'] 	 ***  pulmonaryhypertension
# YES:  pulmonaryhypertension <==> ['Pulmonary hypertension' 'Disease' 'D006976'] 	 ***  pulmonaryhypertension
# YES:  pulmonaryhypertension <==> ['Pulmonary hypertension' 'Disease' 'D006976'] 	 ***  pulmonaryhypertension
# YES:  fenfluramines <==> ['fenfluramines' 'Chemical' 'D005277'] 	 ***  fenfluramines
# YES:  fenfluramines <==> ['fenfluramines' 'Chemical' 'D005277'] 	 ***  fenfluramines
# YES:  fenfluramines <==> ['fenfluramines' 'Chemical' 'D005277'] 	 ***  fenfluramines
# YES:  pulmonaryhypertension <==> ['Pulmonary hypertension' 'Disease' 'D006976'] 	 ***  pulmonaryhypertension
# YES:  heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  thrombocytopenia <==> ['thrombocytopenia' 'Disease' 'D013921'] 	 ***  thrombocytopenia
# YES:  thrombosis <==> ['thrombosis' 'Disease' 'D013927'] 	 ***  thrombosis
# YES:  heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  Heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  thrombosis <==> ['thrombosis' 'Disease' 'D013927'] 	 ***  thrombosis
# YES:  heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  thrombotic <==> ['thrombotic' 'Disease' 'D013927'] 	 ***  thrombotic
# YES:  heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  Bleeding <==> ['bleeding' 'Disease' 'D006470'] 	 ***  bleeding
# YES:  heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  bleeding <==> ['bleeding' 'Disease' 'D006470'] 	 ***  bleeding
# YES:  heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  thrombocytopenia <==> ['thrombocytopenia' 'Disease' 'D013921'] 	 ***  thrombocytopenia
# YES:  heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  osteoporosis <==> ['osteoporosis' 'Disease' 'D010024'] 	 ***  osteoporosis
# YES:  eosinophilia <==> ['eosinophilia' 'Disease' 'D004802'] 	 ***  eosinophilia
# YES:  allergicreactions <==> ['allergic reactions' 'Disease' 'D004342'] 	 ***  allergicreactions
# YES:  thrombocytopenia <==> ['thrombocytopenia' 'Disease' 'D013921'] 	 ***  thrombocytopenia
# YES:  alopecia <==> ['Alopecia' 'Disease' 'D000505'] 	 ***  alopecia
# YES:  hyperkalemia <==> ['Hyperkalemia' 'Disease' 'D006947'] 	 ***  hyperkalemia
# YES:  priapism <==> ['Priapism' 'Disease' 'D011317'] 	 ***  priapism
# YES:  heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  HITT <==> ['HITT' 'Disease' 'D013921'] 	 ***  hitt
# YES:  osteoporosis <==> ['osteoporosis' 'Disease' 'D010024'] 	 ***  osteoporosis
# YES:  heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  tacrolimus <==> ['Tacrolimus' 'Chemical' 'D016559'] 	 ***  tacrolimus
# YES:  FK506 <==> ['FK506' 'Chemical' 'D016559'] 	 ***  fk506
# YES:  tacrolimus <==> ['Tacrolimus' 'Chemical' 'D016559'] 	 ***  tacrolimus
# YES:  FK506 <==> ['FK506' 'Chemical' 'D016559'] 	 ***  fk506
# YES:  tacrolimus <==> ['Tacrolimus' 'Chemical' 'D016559'] 	 ***  tacrolimus
# YES:  tacrolimus <==> ['Tacrolimus' 'Chemical' 'D016559'] 	 ***  tacrolimus
# YES:  Tacrolimus <==> ['Tacrolimus' 'Chemical' 'D016559'] 	 ***  tacrolimus
# YES:  Hypercalcemia <==> ['hypercalcemia' 'Disease' 'D006934'] 	 ***  hypercalcemia
# YES:  arrhythmia <==> ['arrhythmia' 'Disease' 'D001145'] 	 ***  arrhythmia
# YES:  bipolar <==> ['bipolar' 'Disease' 'D001714'] 	 ***  bipolar
# YES:  lithium <==> ['Lithium' 'Chemical' 'D008094'] 	 ***  lithium
# YES:  hypercalcemia <==> ['hypercalcemia' 'Disease' 'D006934'] 	 ***  hypercalcemia
# YES:  bipolar <==> ['bipolar' 'Disease' 'D001714'] 	 ***  bipolar
# YES:  lithium <==> ['Lithium' 'Chemical' 'D008094'] 	 ***  lithium
# YES:  hypercalcemia <==> ['hypercalcemia' 'Disease' 'D006934'] 	 ***  hypercalcemia
# YES:  hypercalcemia <==> ['hypercalcemia' 'Disease' 'D006934'] 	 ***  hypercalcemia
# YES:  lithium <==> ['Lithium' 'Chemical' 'D008094'] 	 ***  lithium
# YES:  malignancies <==> ['malignancies' 'Disease' 'D009369'] 	 ***  malignancies
# YES:  lithium <==> ['Lithium' 'Chemical' 'D008094'] 	 ***  lithium
# YES:  hypercalcemia <==> ['hypercalcemia' 'Disease' 'D006934'] 	 ***  hypercalcemia
# YES:  lithium <==> ['Lithium' 'Chemical' 'D008094'] 	 ***  lithium
# YES:  bipolar <==> ['bipolar' 'Disease' 'D001714'] 	 ***  bipolar
# YES:  bipolar <==> ['bipolar' 'Disease' 'D001714'] 	 ***  bipolar
# YES:  hypercalcemia <==> ['hypercalcemia' 'Disease' 'D006934'] 	 ***  hypercalcemia
# YES:  bipolar <==> ['bipolar' 'Disease' 'D001714'] 	 ***  bipolar
# YES:  lithium <==> ['Lithium' 'Chemical' 'D008094'] 	 ***  lithium
# YES:  hypercalcemia <==> ['hypercalcemia' 'Disease' 'D006934'] 	 ***  hypercalcemia
# YES:  nephrotoxicity <==> ['Nephrotoxicity' 'Disease' 'D007674'] 	 ***  nephrotoxicity
# YES:  amphotericinB <==> ['amphotericin B' 'Chemical' 'D000666'] 	 ***  amphotericinb
# YES:  amphotericinB <==> ['amphotericin B' 'Chemical' 'D000666'] 	 ***  amphotericinb
# YES:  toxicity <==> ['Toxicity' 'Disease' 'D064420'] 	 ***  toxicity
# YES:  toxicity <==> ['Toxicity' 'Disease' 'D064420'] 	 ***  toxicity
# YES:  amphotericinB <==> ['amphotericin B' 'Chemical' 'D000666'] 	 ***  amphotericinb
# YES:  urea <==> ['urea' 'Chemical' 'D014508'] 	 ***  urea
# YES:  creatinine <==> ['creatinine' 'Chemical' 'D003404'] 	 ***  creatinine
# YES:  tubularnecrosis <==> ['tubular necrosis' 'Disease' 'D007683'] 	 ***  tubularnecrosis
# YES:  AmphotericinB <==> ['amphotericin B' 'Chemical' 'D000666'] 	 ***  amphotericinb
# YES:  amphotericinB <==> ['amphotericin B' 'Chemical' 'D000666'] 	 ***  amphotericinb
# YES:  nephrotoxicity <==> ['Nephrotoxicity' 'Disease' 'D007674'] 	 ***  nephrotoxicity
# YES:  amphotericinB <==> ['amphotericin B' 'Chemical' 'D000666'] 	 ***  amphotericinb
# YES:  oliguria <==> ['oliguria' 'Disease' 'D009846'] 	 ***  oliguria
# YES:  abdominalpain <==> ['abdominal pain' 'Disease' 'D015746'] 	 ***  abdominalpain
# YES:  renalfailure <==> ['renal failure' 'Disease' 'D051437'] 	 ***  renalfailure
# YES:  renalcalculi <==> ['renal calculi' 'Disease' 'D007669'] 	 ***  renalcalculi
# YES:  morphine <==> ['Morphine' 'Chemical' 'D009020'] 	 ***  morphine
# YES:  dizziness <==> ['Dizziness' 'Disease' 'D004244'] 	 ***  dizziness
# YES:  morphine <==> ['Morphine' 'Chemical' 'D009020'] 	 ***  morphine
# YES:  morphine <==> ['Morphine' 'Chemical' 'D009020'] 	 ***  morphine
# YES:  morphine <==> ['Morphine' 'Chemical' 'D009020'] 	 ***  morphine
# YES:  amiodarone <==> ['Amiodarone' 'Chemical' 'D000638'] 	 ***  amiodarone
# YES:  myocardialinfarction <==> ['Myocardial infarction' 'Disease' 'D009203'] 	 ***  myocardialinfarction
# YES:  amiodarone <==> ['Amiodarone' 'Chemical' 'D000638'] 	 ***  amiodarone
# YES:  amiodarone <==> ['Amiodarone' 'Chemical' 'D000638'] 	 ***  amiodarone
# YES:  myocardialinfarction <==> ['Myocardial infarction' 'Disease' 'D009203'] 	 ***  myocardialinfarction
# YES:  amiodarone <==> ['Amiodarone' 'Chemical' 'D000638'] 	 ***  amiodarone
# YES:  isoproterenol <==> ['Isoproterenol' 'Chemical' 'D007545'] 	 ***  isoproterenol
# YES:  amiodarone <==> ['Amiodarone' 'Chemical' 'D000638'] 	 ***  amiodarone
# YES:  amiodarone <==> ['Amiodarone' 'Chemical' 'D000638'] 	 ***  amiodarone
# YES:  tachycardia <==> ['tachycardia' 'Disease' 'D013610'] 	 ***  tachycardia
# YES:  isoproterenol <==> ['Isoproterenol' 'Chemical' 'D007545'] 	 ***  isoproterenol
# YES:  tachycardia <==> ['tachycardia' 'Disease' 'D013610'] 	 ***  tachycardia
# YES:  amiodarone <==> ['Amiodarone' 'Chemical' 'D000638'] 	 ***  amiodarone
# YES:  arrhythmias <==> ['arrhythmias' 'Disease' 'D001145'] 	 ***  arrhythmias
# YES:  doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  paclitaxel <==> ['Paclitaxel' 'Chemical' 'D017239'] 	 ***  paclitaxel
# YES:  doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  ovariancancer <==> ['ovarian cancer' 'Disease' 'D010051'] 	 ***  ovariancancer
# YES:  toxicity <==> ['Toxicity' 'Disease' 'D064420'] 	 ***  toxicity
# YES:  hand-footsyndrome <==> ['hand-foot syndrome' 'Disease' 'D060831'] 	 ***  handfootsyndrome
# YES:  stomatitis <==> ['stomatitis' 'Disease' 'D013280'] 	 ***  stomatitis
# YES:  doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  paclitaxel <==> ['Paclitaxel' 'Chemical' 'D017239'] 	 ***  paclitaxel
# YES:  paclitaxel <==> ['Paclitaxel' 'Chemical' 'D017239'] 	 ***  paclitaxel
# YES:  doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  hand-footsyndrome <==> ['hand-foot syndrome' 'Disease' 'D060831'] 	 ***  handfootsyndrome
# YES:  stomatitis <==> ['stomatitis' 'Disease' 'D013280'] 	 ***  stomatitis
# YES:  diarrhea <==> ['diarrhea' 'Disease' 'D003967'] 	 ***  diarrhea
# YES:  doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  toxicity <==> ['Toxicity' 'Disease' 'D064420'] 	 ***  toxicity
# YES:  stomatitis <==> ['stomatitis' 'Disease' 'D013280'] 	 ***  stomatitis
# YES:  hand-footsyndrome <==> ['hand-foot syndrome' 'Disease' 'D060831'] 	 ***  handfootsyndrome
# YES:  paclitaxel <==> ['Paclitaxel' 'Chemical' 'D017239'] 	 ***  paclitaxel
# YES:  ovariancancer <==> ['ovarian cancer' 'Disease' 'D010051'] 	 ***  ovariancancer
# YES:  olanzapine <==> ['olanzapine' 'Chemical' 'C076029'] 	 ***  olanzapine
# YES:  olanzapine <==> ['olanzapine' 'Chemical' 'C076029'] 	 ***  olanzapine
# YES:  bipolardisorder <==> ['bipolar disorder' 'Disease' 'D001714'] 	 ***  bipolardisorder
# YES:  manic <==> ['Manic' 'Disease' 'D001714'] 	 ***  manic
# YES:  olanzapine <==> ['olanzapine' 'Chemical' 'C076029'] 	 ***  olanzapine
# YES:  Mania <==> ['mania' 'Disease' 'D001714'] 	 ***  mania
# YES:  EPS <==> ['EPS' 'Disease' 'D001480'] 	 ***  eps
# YES:  Olanzapine <==> ['olanzapine' 'Chemical' 'C076029'] 	 ***  olanzapine
# YES:  Olanzapine <==> ['olanzapine' 'Chemical' 'C076029'] 	 ***  olanzapine
# YES:  olanzapine <==> ['olanzapine' 'Chemical' 'C076029'] 	 ***  olanzapine
# YES:  weightgain <==> ['weight gain' 'Disease' 'D015430'] 	 ***  weightgain
# YES:  somnolence <==> ['somnolence' 'Disease' 'D006970'] 	 ***  somnolence
# YES:  Olanzapine <==> ['olanzapine' 'Chemical' 'C076029'] 	 ***  olanzapine
# YES:  stressincontinence <==> ['stress incontinence' 'Disease' 'D014550'] 	 ***  stressincontinence
# YES:  stressincontinence <==> ['stress incontinence' 'Disease' 'D014550'] 	 ***  stressincontinence
# YES:  headache <==> ['Headache' 'Disease' 'D006261'] 	 ***  headache
# YES:  stressincontinence <==> ['stress incontinence' 'Disease' 'D014550'] 	 ***  stressincontinence
# YES:  glucose <==> ['glucose' 'Chemical' 'D005947'] 	 ***  glucose
# YES:  glucosuria <==> ['glucosuria' 'Disease' 'D006030'] 	 ***  glucosuria
# YES:  glutamate <==> ['glutamate' 'Chemical' 'D018698'] 	 ***  glutamate
# YES:  methionine <==> ['methionine' 'Chemical' 'D008715'] 	 ***  methionine
# YES:  heartfailure <==> ['heart failure' 'Disease' 'D006333'] 	 ***  heartfailure
# YES:  Lisinopril <==> ['lisinopril' 'Chemical' 'D017706'] 	 ***  lisinopril
# YES:  angiotensin-convertingenzyme(ACE)inhibitors <==> ['angiotensin converting enzyme (ACE) inhibitors' 'Chemical' 'D000806'] 	 ***  angiotensinconvertingenzymeaceinhibitors
# YES:  heartfailure <==> ['heart failure' 'Disease' 'D006333'] 	 ***  heartfailure
# YES:  CHF <==> ['CHF' 'Disease' 'D006333'] 	 ***  chf
# YES:  lisinopril <==> ['lisinopril' 'Chemical' 'D017706'] 	 ***  lisinopril
# YES:  CHF <==> ['CHF' 'Disease' 'D006333'] 	 ***  chf
# YES:  Lisinopril <==> ['lisinopril' 'Chemical' 'D017706'] 	 ***  lisinopril
# YES:  ACEinhibitor <==> ['ACE inhibitor' 'Chemical' 'D000806'] 	 ***  aceinhibitor
# YES:  lisinopril <==> ['lisinopril' 'Chemical' 'D017706'] 	 ***  lisinopril
# YES:  CHF <==> ['CHF' 'Disease' 'D006333'] 	 ***  chf
# YES:  hypotension <==> ['Hypotension' 'Disease' 'D007022'] 	 ***  hypotension
# YES:  renaldysfunction <==> ['renal dysfunction' 'Disease' 'D007674'] 	 ***  renaldysfunction
# YES:  ACEinhibitor <==> ['ACE inhibitor' 'Chemical' 'D000806'] 	 ***  aceinhibitor
# YES:  hypotension <==> ['Hypotension' 'Disease' 'D007022'] 	 ***  hypotension
# YES:  renaldysfunction <==> ['renal dysfunction' 'Disease' 'D007674'] 	 ***  renaldysfunction
# YES:  hyperkalemia <==> ['Hyperkalemia' 'Disease' 'D006947'] 	 ***  hyperkalemia
# YES:  ACEinhibitor <==> ['ACE inhibitor' 'Chemical' 'D000806'] 	 ***  aceinhibitor
# YES:  creatinine <==> ['creatinine' 'Chemical' 'D003404'] 	 ***  creatinine
# YES:  diabetes <==> ['diabetes' 'Disease' 'D003920'] 	 ***  diabetes
# YES:  ACEinhibitor <==> ['ACE inhibitor' 'Chemical' 'D000806'] 	 ***  aceinhibitor
# YES:  CHF <==> ['CHF' 'Disease' 'D006333'] 	 ***  chf
# YES:  Cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  ethanol <==> ['ethanol' 'Chemical' 'D000431'] 	 ***  ethanol
# YES:  cardiactoxicity <==> ['Cardiac toxicity' 'Disease' 'D066126'] 	 ***  cardiactoxicity
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  ethanol <==> ['ethanol' 'Chemical' 'D000431'] 	 ***  ethanol
# YES:  cardiotoxicity <==> ['cardiotoxicity' 'Disease' 'D066126'] 	 ***  cardiotoxicity
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  ethanol <==> ['ethanol' 'Chemical' 'D000431'] 	 ***  ethanol
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  ethanol <==> ['ethanol' 'Chemical' 'D000431'] 	 ***  ethanol
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  ethanol <==> ['ethanol' 'Chemical' 'D000431'] 	 ***  ethanol
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  Ventriculararrhythmias <==> ['ventricular arrhythmias' 'Disease' 'D001145'] 	 ***  ventriculararrhythmias
# YES:  ventriculartachycardia <==> ['ventricular tachycardia' 'Disease' 'D017180'] 	 ***  ventriculartachycardia
# YES:  Cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  ethanol <==> ['ethanol' 'Chemical' 'D000431'] 	 ***  ethanol
# YES:  cardiactoxicity <==> ['Cardiac toxicity' 'Disease' 'D066126'] 	 ***  cardiactoxicity
# YES:  Parkinsonism <==> ['parkinsonism' 'Disease' 'D010302'] 	 ***  parkinsonism
# YES:  Parkinson'sdisease <==> ["Parkinson's Disease" 'Disease' 'D010300'] 	 ***  parkinsonsdisease
# YES:  bradycardia <==> ['Bradycardia' 'Disease' 'D001919'] 	 ***  bradycardia
# YES:  Bradycardia <==> ['Bradycardia' 'Disease' 'D001919'] 	 ***  bradycardia
# YES:  Graves'disease <==> ["Graves' disease" 'Disease' 'D006111'] 	 ***  gravesdisease
# YES:  propylthiouracil <==> ['Propylthiouracil' 'Chemical' 'D011441'] 	 ***  propylthiouracil
# YES:  vasculitis <==> ['vasculitis' 'Disease' 'D014657'] 	 ***  vasculitis
# YES:  Graves'disease <==> ["Graves' disease" 'Disease' 'D006111'] 	 ***  gravesdisease
# YES:  propylthiouracil <==> ['Propylthiouracil' 'Chemical' 'D011441'] 	 ***  propylthiouracil
# YES:  vasculitis <==> ['vasculitis' 'Disease' 'D014657'] 	 ***  vasculitis
# YES:  Graves'disease <==> ["Graves' disease" 'Disease' 'D006111'] 	 ***  gravesdisease
# YES:  Graves'disease <==> ["Graves' disease" 'Disease' 'D006111'] 	 ***  gravesdisease
# YES:  hyperthyroidism <==> ['hyperthyroidism' 'Disease' 'D006980'] 	 ***  hyperthyroidism
# YES:  Graves'disease <==> ["Graves' disease" 'Disease' 'D006111'] 	 ***  gravesdisease
# YES:  vasculitis <==> ['vasculitis' 'Disease' 'D014657'] 	 ***  vasculitis
# YES:  Graves'disease <==> ["Graves' disease" 'Disease' 'D006111'] 	 ***  gravesdisease
# YES:  fever <==> ['fever' 'Disease' 'D005334'] 	 ***  fever
# YES:  vasculitis <==> ['vasculitis' 'Disease' 'D014657'] 	 ***  vasculitis
# YES:  heartdisease <==> ['heart disease' 'Disease' 'D006331'] 	 ***  heartdisease
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  heartdisease <==> ['heart disease' 'Disease' 'D006331'] 	 ***  heartdisease
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  coronaryarterydisease <==> ['coronary artery disease' 'Disease' 'D003324'] 	 ***  coronaryarterydisease
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  isoproterenol <==> ['Isoproterenol' 'Chemical' 'D007545'] 	 ***  isoproterenol
# YES:  ethanol <==> ['ethanol' 'Chemical' 'D000431'] 	 ***  ethanol
# YES:  isoproterenol <==> ['Isoproterenol' 'Chemical' 'D007545'] 	 ***  isoproterenol
# YES:  myocardialinfarction <==> ['Myocardial infarction' 'Disease' 'D009203'] 	 ***  myocardialinfarction
# YES:  isoproterenol <==> ['Isoproterenol' 'Chemical' 'D007545'] 	 ***  isoproterenol
# YES:  myocardialinfarction <==> ['Myocardial infarction' 'Disease' 'D009203'] 	 ***  myocardialinfarction
# YES:  ventriculartachycardia <==> ['ventricular tachycardia' 'Disease' 'D017180'] 	 ***  ventriculartachycardia
# YES:  long-QTsyndrome <==> ['long QT syndrome' 'Disease' 'D008133'] 	 ***  longqtsyndrome
# YES:  TdP <==> ['TDP' 'Disease' 'D016171'] 	 ***  tdp
# YES:  QTprolongation <==> ['Q-T prolongation' 'Disease' 'D008133'] 	 ***  qtprolongation
# YES:  TdP <==> ['TDP' 'Disease' 'D016171'] 	 ***  tdp
# YES:  QTprolongation <==> ['Q-T prolongation' 'Disease' 'D008133'] 	 ***  qtprolongation
# YES:  QTprolongation <==> ['Q-T prolongation' 'Disease' 'D008133'] 	 ***  qtprolongation
# YES:  TdP <==> ['TDP' 'Disease' 'D016171'] 	 ***  tdp
# YES:  TdP <==> ['TDP' 'Disease' 'D016171'] 	 ***  tdp
# YES:  QTprolongation <==> ['Q-T prolongation' 'Disease' 'D008133'] 	 ***  qtprolongation
# YES:  dobutamine <==> ['Dobutamine' 'Chemical' 'D004280'] 	 ***  dobutamine
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  chestpain <==> ['chest pain' 'Disease' 'D002637'] 	 ***  chestpain
# YES:  Chestpain <==> ['chest pain' 'Disease' 'D002637'] 	 ***  chestpain
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  Dobutamine <==> ['Dobutamine' 'Chemical' 'D004280'] 	 ***  dobutamine
# YES:  ischemia <==> ['ischemia' 'Disease' 'D007511'] 	 ***  ischemia
# YES:  dobutamine <==> ['Dobutamine' 'Chemical' 'D004280'] 	 ***  dobutamine
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  chestpain <==> ['chest pain' 'Disease' 'D002637'] 	 ***  chestpain
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  chestpain <==> ['chest pain' 'Disease' 'D002637'] 	 ***  chestpain
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  toxicity <==> ['Toxicity' 'Disease' 'D064420'] 	 ***  toxicity
# YES:  atropine <==> ['Atropine' 'Chemical' 'D001285'] 	 ***  atropine
# YES:  dobutamine <==> ['Dobutamine' 'Chemical' 'D004280'] 	 ***  dobutamine
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  chestpain <==> ['chest pain' 'Disease' 'D002637'] 	 ***  chestpain
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  hemorrhage <==> ['hemorrhage' 'Disease' 'D006470'] 	 ***  hemorrhage
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  cocaineabuse <==> ['cocaine abuse' 'Disease' 'D019970'] 	 ***  cocaineabuse
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  Thalidomide <==> ['Thalidomide' 'Chemical' 'D013792'] 	 ***  thalidomide
# YES:  neuropathy <==> ['neuropathy' 'Disease' 'D009422'] 	 ***  neuropathy
# YES:  prostatecancer <==> ['prostate cancer' 'Disease' 'D011471'] 	 ***  prostatecancer
# YES:  thalidomide <==> ['Thalidomide' 'Chemical' 'D013792'] 	 ***  thalidomide
# YES:  neuropathy <==> ['neuropathy' 'Disease' 'D009422'] 	 ***  neuropathy
# YES:  prostatecancer <==> ['prostate cancer' 'Disease' 'D011471'] 	 ***  prostatecancer
# YES:  thalidomide <==> ['Thalidomide' 'Chemical' 'D013792'] 	 ***  thalidomide
# YES:  Thalidomide <==> ['Thalidomide' 'Chemical' 'D013792'] 	 ***  thalidomide
# YES:  thalidomide <==> ['Thalidomide' 'Chemical' 'D013792'] 	 ***  thalidomide
# YES:  neuropathy <==> ['neuropathy' 'Disease' 'D009422'] 	 ***  neuropathy
# YES:  Neuropathy <==> ['neuropathy' 'Disease' 'D009422'] 	 ***  neuropathy
# YES:  thalidomide <==> ['Thalidomide' 'Chemical' 'D013792'] 	 ***  thalidomide
# YES:  peripheralneuropathy <==> ['Peripheral neuropathy' 'Disease' 'D010523'] 	 ***  peripheralneuropathy
# YES:  superoxide <==> ['superoxide' 'Chemical' 'D013481'] 	 ***  superoxide
# YES:  kanamycin <==> ['kanamycin' 'Chemical' 'D007612'] 	 ***  kanamycin
# YES:  hearingloss <==> ['hearing loss' 'Disease' 'D034381'] 	 ***  hearingloss
# YES:  oxygen <==> ['oxygen' 'Chemical' 'D010100'] 	 ***  oxygen
# YES:  aminoglycoside <==> ['Aminoglycoside' 'Chemical' 'D000617'] 	 ***  aminoglycoside
# YES:  ototoxicity <==> ['Ototoxicity' 'Disease' 'D006311'] 	 ***  ototoxicity
# YES:  aminoglycoside <==> ['Aminoglycoside' 'Chemical' 'D000617'] 	 ***  aminoglycoside
# YES:  iron <==> ['iron' 'Chemical' 'D007501'] 	 ***  iron
# YES:  superoxide <==> ['superoxide' 'Chemical' 'D013481'] 	 ***  superoxide
# YES:  ototoxicity <==> ['Ototoxicity' 'Disease' 'D006311'] 	 ***  ototoxicity
# YES:  superoxide <==> ['superoxide' 'Chemical' 'D013481'] 	 ***  superoxide
# YES:  ototoxicity <==> ['Ototoxicity' 'Disease' 'D006311'] 	 ***  ototoxicity
# YES:  kanamycin <==> ['kanamycin' 'Chemical' 'D007612'] 	 ***  kanamycin
# YES:  kanamycin <==> ['kanamycin' 'Chemical' 'D007612'] 	 ***  kanamycin
# YES:  kanamycin <==> ['kanamycin' 'Chemical' 'D007612'] 	 ***  kanamycin
# YES:  superoxide <==> ['superoxide' 'Chemical' 'D013481'] 	 ***  superoxide
# YES:  aminoglycoside <==> ['Aminoglycoside' 'Chemical' 'D000617'] 	 ***  aminoglycoside
# YES:  ototoxicity <==> ['Ototoxicity' 'Disease' 'D006311'] 	 ***  ototoxicity
# YES:  depression <==> ['Depression' 'Disease' 'D003866'] 	 ***  depression
# YES:  depression <==> ['Depression' 'Disease' 'D003866'] 	 ***  depression
# YES:  Prednisone <==> ['prednisone' 'Chemical' 'D011241'] 	 ***  prednisone
# YES:  anxiety <==> ['anxiety' 'Disease' 'D001008'] 	 ***  anxiety
# YES:  prednisone <==> ['prednisone' 'Chemical' 'D011241'] 	 ***  prednisone
# YES:  anxiety <==> ['anxiety' 'Disease' 'D001008'] 	 ***  anxiety
# YES:  Anxiety <==> ['anxiety' 'Disease' 'D001008'] 	 ***  anxiety
# YES:  Anxiety <==> ['anxiety' 'Disease' 'D001008'] 	 ***  anxiety
# YES:  anxiety <==> ['anxiety' 'Disease' 'D001008'] 	 ***  anxiety
# YES:  carboplatin <==> ['carboplatin' 'Chemical' 'D016190'] 	 ***  carboplatin
# YES:  doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  carboplatin <==> ['carboplatin' 'Chemical' 'D016190'] 	 ***  carboplatin
# YES:  doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  carboplatin <==> ['carboplatin' 'Chemical' 'D016190'] 	 ***  carboplatin
# YES:  doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  toxicity <==> ['Toxicity' 'Disease' 'D064420'] 	 ***  toxicity
# YES:  toxicity <==> ['Toxicity' 'Disease' 'D064420'] 	 ***  toxicity
# YES:  myelosuppression <==> ['Myelosuppression' 'Disease' 'D001855'] 	 ***  myelosuppression
# YES:  neutropenia <==> ['Neutropenia' 'Disease' 'D009503'] 	 ***  neutropenia
# YES:  anemia <==> ['anemia' 'Disease' 'D000740'] 	 ***  anemia
# YES:  thrombocytopenia <==> ['thrombocytopenia' 'Disease' 'D013921'] 	 ***  thrombocytopenia
# YES:  doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  toxicity <==> ['Toxicity' 'Disease' 'D064420'] 	 ***  toxicity
# YES:  nausea <==> ['nausea' 'Disease' 'D009325'] 	 ***  nausea
# YES:  emesis <==> ['emesis' 'Disease' 'D014839'] 	 ***  emesis
# YES:  fatigue <==> ['fatigue' 'Disease' 'D005221'] 	 ***  fatigue
# YES:  mucositis <==> ['mucositis' 'Disease' 'D052016'] 	 ***  mucositis
# YES:  stomatitis <==> ['stomatitis' 'Disease' 'D013280'] 	 ***  stomatitis
# YES:  constipation <==> ['constipation' 'Disease' 'D003248'] 	 ***  constipation
# YES:  weightloss <==> ['weight loss' 'Disease' 'D015431'] 	 ***  weightloss
# YES:  hand-footsyndrome <==> ['hand-foot syndrome' 'Disease' 'D060831'] 	 ***  handfootsyndrome
# YES:  carboplatin <==> ['carboplatin' 'Chemical' 'D016190'] 	 ***  carboplatin
# YES:  doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  mania <==> ['mania' 'Disease' 'D001714'] 	 ***  mania
# YES:  manic <==> ['Manic' 'Disease' 'D001714'] 	 ***  manic
# YES:  mania <==> ['mania' 'Disease' 'D001714'] 	 ***  mania
# YES:  mania <==> ['mania' 'Disease' 'D001714'] 	 ***  mania
# YES:  isoniazid <==> ['Isoniazid' 'Chemical' 'D007538'] 	 ***  isoniazid
# YES:  amoxicillin <==> ['amoxicillin' 'Chemical' 'D000658'] 	 ***  amoxicillin
# YES:  ciprofloxacin <==> ['ciprofloxacin' 'Chemical' 'D002939'] 	 ***  ciprofloxacin
# YES:  Cotrimoxazole <==> ['co-trimoxazole' 'Chemical' 'D015662'] 	 ***  cotrimoxazole
# YES:  metronidazole <==> ['metronidazole' 'Chemical' 'D008795'] 	 ***  metronidazole
# YES:  manic <==> ['Manic' 'Disease' 'D001714'] 	 ***  manic
# YES:  ciprofloxacin <==> ['ciprofloxacin' 'Chemical' 'D002939'] 	 ***  ciprofloxacin
# YES:  mania <==> ['mania' 'Disease' 'D001714'] 	 ***  mania
# YES:  mania <==> ['mania' 'Disease' 'D001714'] 	 ***  mania
# YES:  mania <==> ['mania' 'Disease' 'D001714'] 	 ***  mania
# YES:  manic <==> ['Manic' 'Disease' 'D001714'] 	 ***  manic
# YES:  Levodopa <==> ['Levodopa' 'Chemical' 'D007980'] 	 ***  levodopa
# YES:  Parkinson'sdisease <==> ["Parkinson's Disease" 'Disease' 'D010300'] 	 ***  parkinsonsdisease
# YES:  Levodopa <==> ['Levodopa' 'Chemical' 'D007980'] 	 ***  levodopa
# YES:  levodopa <==> ['Levodopa' 'Chemical' 'D007980'] 	 ***  levodopa
# YES:  levodopa <==> ['Levodopa' 'Chemical' 'D007980'] 	 ***  levodopa
# YES:  diclofenac <==> ['diclofenac' 'Chemical' 'D004008'] 	 ***  diclofenac
# YES:  prostaglandins <==> ['prostaglandins' 'Chemical' 'D011453'] 	 ***  prostaglandins
# YES:  nitricoxide <==> ['nitric oxide' 'Chemical' 'D009569'] 	 ***  nitricoxide
# YES:  NO <==> ['NO' 'Chemical' 'D009569'] 	 ***  no
# YES:  NO <==> ['NO' 'Chemical' 'D009569'] 	 ***  no
# YES:  diclofenac <==> ['diclofenac' 'Chemical' 'D004008'] 	 ***  diclofenac
# YES:  pain <==> ['Pain' 'Disease' 'D010146'] 	 ***  pain
# YES:  Headache <==> ['Headache' 'Disease' 'D006261'] 	 ***  headache
# YES:  headache <==> ['Headache' 'Disease' 'D006261'] 	 ***  headache
# YES:  angiotensin <==> ['Angiotensin' 'Chemical' 'D000809'] 	 ***  angiotensin
# YES:  glomerularinjury <==> ['glomerular injury' 'Disease' 'D007674'] 	 ***  glomerularinjury
# YES:  puromycinaminonucleoside <==> ['Puromycin aminonucleoside' 'Chemical' 'D011692'] 	 ***  puromycinaminonucleoside
# YES:  nephrosis <==> ['nephrosis' 'Disease' 'D009401'] 	 ***  nephrosis
# YES:  angiotensin <==> ['Angiotensin' 'Chemical' 'D000809'] 	 ***  angiotensin
# YES:  proteinuria <==> ['Proteinuria' 'Disease' 'D011507'] 	 ***  proteinuria
# YES:  hypertrophy <==> ['hypertrophy' 'Disease' 'D006984'] 	 ***  hypertrophy
# YES:  glomerulosclerosis <==> ['glomerulosclerosis' 'Disease' 'D005921'] 	 ***  glomerulosclerosis
# YES:  puromycinaminonucleoside <==> ['Puromycin aminonucleoside' 'Chemical' 'D011692'] 	 ***  puromycinaminonucleoside
# YES:  PAN <==> ['PAN' 'Chemical' 'D011692'] 	 ***  pan
# YES:  nephrotic <==> ['nephrotic' 'Disease' 'D009404'] 	 ***  nephrotic
# YES:  Nephrosis <==> ['nephrosis' 'Disease' 'D009401'] 	 ***  nephrosis
# YES:  PAN <==> ['PAN' 'Chemical' 'D011692'] 	 ***  pan
# YES:  PAN <==> ['PAN' 'Chemical' 'D011692'] 	 ***  pan
# YES:  PAN <==> ['PAN' 'Chemical' 'D011692'] 	 ***  pan
# YES:  PAN <==> ['PAN' 'Chemical' 'D011692'] 	 ***  pan
# YES:  PAN <==> ['PAN' 'Chemical' 'D011692'] 	 ***  pan
# YES:  PAN <==> ['PAN' 'Chemical' 'D011692'] 	 ***  pan
# YES:  proteinuria <==> ['Proteinuria' 'Disease' 'D011507'] 	 ***  proteinuria
# YES:  glomerulosclerosis <==> ['glomerulosclerosis' 'Disease' 'D005921'] 	 ***  glomerulosclerosis
# YES:  PAN <==> ['PAN' 'Chemical' 'D011692'] 	 ***  pan
# YES:  PAN <==> ['PAN' 'Chemical' 'D011692'] 	 ***  pan
# YES:  PAN <==> ['PAN' 'Chemical' 'D011692'] 	 ***  pan
# YES:  PAN <==> ['PAN' 'Chemical' 'D011692'] 	 ***  pan
# YES:  Pulmonaryhypertension <==> ['Pulmonary hypertension' 'Disease' 'D006976'] 	 ***  pulmonaryhypertension
# YES:  ibuprofen <==> ['ibuprofen' 'Chemical' 'D007052'] 	 ***  ibuprofen
# YES:  hypoxaemia <==> ['hypoxaemia' 'Disease' 'D000860'] 	 ***  hypoxaemia
# YES:  ibuprofen <==> ['ibuprofen' 'Chemical' 'D007052'] 	 ***  ibuprofen
# YES:  ibuprofen <==> ['ibuprofen' 'Chemical' 'D007052'] 	 ***  ibuprofen
# YES:  Hypoxaemia <==> ['hypoxaemia' 'Disease' 'D000860'] 	 ***  hypoxaemia
# YES:  nitricoxide <==> ['nitric oxide' 'Chemical' 'D009569'] 	 ***  nitricoxide
# YES:  hypoxaemia <==> ['hypoxaemia' 'Disease' 'D000860'] 	 ***  hypoxaemia
# YES:  ibuprofen <==> ['ibuprofen' 'Chemical' 'D007052'] 	 ***  ibuprofen
# YES:  Hyponatremia <==> ['hyponatremia' 'Disease' 'D007010'] 	 ***  hyponatremia
# YES:  Vincristine <==> ['vincristine' 'Chemical' 'D014750'] 	 ***  vincristine
# YES:  hyponatremia <==> ['hyponatremia' 'Disease' 'D007010'] 	 ***  hyponatremia
# YES:  vincristine <==> ['vincristine' 'Chemical' 'D014750'] 	 ***  vincristine
# YES:  hyponatremia <==> ['hyponatremia' 'Disease' 'D007010'] 	 ***  hyponatremia
# YES:  vincristine <==> ['vincristine' 'Chemical' 'D014750'] 	 ***  vincristine
# YES:  hyponatremia <==> ['hyponatremia' 'Disease' 'D007010'] 	 ***  hyponatremia
# YES:  vincristine <==> ['vincristine' 'Chemical' 'D014750'] 	 ***  vincristine
# YES:  leukemia <==> ['Leukemia' 'Disease' 'D007938'] 	 ***  leukemia
# YES:  hyponatremia <==> ['hyponatremia' 'Disease' 'D007010'] 	 ***  hyponatremia
# YES:  vincristine <==> ['vincristine' 'Chemical' 'D014750'] 	 ***  vincristine
# YES:  vincristine <==> ['vincristine' 'Chemical' 'D014750'] 	 ***  vincristine
# YES:  toxicity <==> ['Toxicity' 'Disease' 'D064420'] 	 ***  toxicity
# YES:  cyclophosphamide <==> ['Cyclophosphamide' 'Chemical' 'D003520'] 	 ***  cyclophosphamide
# YES:  cyclophosphamide <==> ['Cyclophosphamide' 'Chemical' 'D003520'] 	 ***  cyclophosphamide
# YES:  CY <==> ['CY' 'Chemical' 'D003520'] 	 ***  cy
# YES:  CY <==> ['CY' 'Chemical' 'D003520'] 	 ***  cy
# YES:  CY <==> ['CY' 'Chemical' 'D003520'] 	 ***  cy
# YES:  toxicity <==> ['Toxicity' 'Disease' 'D064420'] 	 ***  toxicity
# YES:  cystitis <==> ['cystitis' 'Disease' 'D003556'] 	 ***  cystitis
# YES:  CY <==> ['CY' 'Chemical' 'D003520'] 	 ***  cy
# YES:  cystitis <==> ['cystitis' 'Disease' 'D003556'] 	 ***  cystitis
# YES:  cystitis <==> ['cystitis' 'Disease' 'D003556'] 	 ***  cystitis
# YES:  cystitis <==> ['cystitis' 'Disease' 'D003556'] 	 ***  cystitis
# YES:  toxicity <==> ['Toxicity' 'Disease' 'D064420'] 	 ***  toxicity
# YES:  CY <==> ['CY' 'Chemical' 'D003520'] 	 ***  cy
# YES:  5-fluorouracil <==> ['5-fluorouracil' 'Chemical' 'D005472'] 	 ***  5fluorouracil
# YES:  folinicacid <==> ['folinic acid' 'Chemical' 'D002955'] 	 ***  folinicacid
# YES:  5-fluorouracil <==> ['5-fluorouracil' 'Chemical' 'D005472'] 	 ***  5fluorouracil
# YES:  5-FU <==> ['5-FU' 'Chemical' 'D005472'] 	 ***  5fu
# YES:  folinicacid <==> ['folinic acid' 'Chemical' 'D002955'] 	 ***  folinicacid
# YES:  toxicity <==> ['Toxicity' 'Disease' 'D064420'] 	 ***  toxicity
# YES:  5-FU <==> ['5-FU' 'Chemical' 'D005472'] 	 ***  5fu
# YES:  toxicity <==> ['Toxicity' 'Disease' 'D064420'] 	 ***  toxicity
# YES:  5-FU <==> ['5-FU' 'Chemical' 'D005472'] 	 ***  5fu
# YES:  5-FU <==> ['5-FU' 'Chemical' 'D005472'] 	 ***  5fu
# YES:  toxicities <==> ['toxicities' 'Disease' 'D064420'] 	 ***  toxicities
# YES:  leukopenia <==> ['leukopenia' 'Disease' 'D007970'] 	 ***  leukopenia
# YES:  thrombocytopenia <==> ['thrombocytopenia' 'Disease' 'D013921'] 	 ***  thrombocytopenia
# YES:  diarrhea <==> ['diarrhea' 'Disease' 'D003967'] 	 ***  diarrhea
# YES:  stomatitis <==> ['stomatitis' 'Disease' 'D013280'] 	 ***  stomatitis
# YES:  hand-footsyndrome <==> ['hand-foot syndrome' 'Disease' 'D060831'] 	 ***  handfootsyndrome
# YES:  hemolytic-uremicsyndrome <==> ['hemolytic-uremic syndrome' 'Disease' 'D006463'] 	 ***  hemolyticuremicsyndrome
# YES:  HUS <==> ['HUS' 'Disease' 'D006463'] 	 ***  hus
# YES:  5-FU <==> ['5-FU' 'Chemical' 'D005472'] 	 ***  5fu
# YES:  cisplatin <==> ['Cisplatin' 'Chemical' 'D002945'] 	 ***  cisplatin
# YES:  HUS <==> ['HUS' 'Disease' 'D006463'] 	 ***  hus
# YES:  impairedrenalfunction <==> ['impaired renal function' 'Disease' 'D007674'] 	 ***  impairedrenalfunction
# YES:  indinavir <==> ['indinavir' 'Chemical' 'D019469'] 	 ***  indinavir
# YES:  indinavir <==> ['indinavir' 'Chemical' 'D019469'] 	 ***  indinavir
# YES:  indinavir <==> ['indinavir' 'Chemical' 'D019469'] 	 ***  indinavir
# YES:  nephrotoxicity <==> ['Nephrotoxicity' 'Disease' 'D007674'] 	 ***  nephrotoxicity
# YES:  indinavir <==> ['indinavir' 'Chemical' 'D019469'] 	 ***  indinavir
# YES:  creatinine <==> ['creatinine' 'Chemical' 'D003404'] 	 ***  creatinine
# YES:  creatinine <==> ['creatinine' 'Chemical' 'D003404'] 	 ***  creatinine
# YES:  indinavir <==> ['indinavir' 'Chemical' 'D019469'] 	 ***  indinavir
# YES:  indinavir <==> ['indinavir' 'Chemical' 'D019469'] 	 ***  indinavir
# YES:  creatinine <==> ['creatinine' 'Chemical' 'D003404'] 	 ***  creatinine
# YES:  hematuria <==> ['hematuria' 'Disease' 'D006417'] 	 ***  hematuria
# YES:  creatinine <==> ['creatinine' 'Chemical' 'D003404'] 	 ***  creatinine
# YES:  creatinine <==> ['creatinine' 'Chemical' 'D003404'] 	 ***  creatinine
# YES:  indinavir <==> ['indinavir' 'Chemical' 'D019469'] 	 ***  indinavir
# YES:  indinavir <==> ['indinavir' 'Chemical' 'D019469'] 	 ***  indinavir
# YES:  nephrotoxicity <==> ['Nephrotoxicity' 'Disease' 'D007674'] 	 ***  nephrotoxicity
# YES:  creatinine <==> ['creatinine' 'Chemical' 'D003404'] 	 ***  creatinine
# YES:  creatinine <==> ['creatinine' 'Chemical' 'D003404'] 	 ***  creatinine
# YES:  indinavir <==> ['indinavir' 'Chemical' 'D019469'] 	 ***  indinavir
# YES:  creatinine <==> ['creatinine' 'Chemical' 'D003404'] 	 ***  creatinine
# YES:  nephrolithiasis <==> ['Nephrolithiasis' 'Disease' 'D053040'] 	 ***  nephrolithiasis
# YES:  Indinavir <==> ['indinavir' 'Chemical' 'D019469'] 	 ***  indinavir
# YES:  nephrotoxicity <==> ['Nephrotoxicity' 'Disease' 'D007674'] 	 ***  nephrotoxicity
# YES:  indinavir <==> ['indinavir' 'Chemical' 'D019469'] 	 ***  indinavir
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  chestpain <==> ['chest pain' 'Disease' 'D002637'] 	 ***  chestpain
# YES:  myocardialnecrosis <==> ['myocardial necrosis' 'Disease' 'D009202'] 	 ***  myocardialnecrosis
# YES:  myocardialinfarction <==> ['Myocardial infarction' 'Disease' 'D009203'] 	 ***  myocardialinfarction
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  chestpain <==> ['chest pain' 'Disease' 'D002637'] 	 ***  chestpain
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  chestpain <==> ['chest pain' 'Disease' 'D002637'] 	 ***  chestpain
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  creatine <==> ['creatine' 'Chemical' 'D003401'] 	 ***  creatine
# YES:  necrosis <==> ['necrosis' 'Disease' 'D009336'] 	 ***  necrosis
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  chestpain <==> ['chest pain' 'Disease' 'D002637'] 	 ***  chestpain
# YES:  interstitialnephritis <==> ['interstitial nephritis' 'Disease' 'D009395'] 	 ***  interstitialnephritis
# YES:  interstitialnephritis <==> ['interstitial nephritis' 'Disease' 'D009395'] 	 ***  interstitialnephritis
# YES:  fever <==> ['fever' 'Disease' 'D005334'] 	 ***  fever
# YES:  acuterenalfailure <==> ['acute renal failure' 'Disease' 'D058186'] 	 ***  acuterenalfailure
# YES:  retinalveinocclusion <==> ['retinal vein occlusion' 'Disease' 'D012170'] 	 ***  retinalveinocclusion
# YES:  fever <==> ['fever' 'Disease' 'D005334'] 	 ***  fever
# YES:  fever <==> ['fever' 'Disease' 'D005334'] 	 ***  fever
# YES:  eosinophilia <==> ['eosinophilia' 'Disease' 'D004802'] 	 ***  eosinophilia
# YES:  renalfailure <==> ['renal failure' 'Disease' 'D051437'] 	 ***  renalfailure
# YES:  methylprednisolone <==> ['methylprednisolone' 'Chemical' 'D008775'] 	 ***  methylprednisolone
# YES:  bleeding <==> ['bleeding' 'Disease' 'D006470'] 	 ***  bleeding
# YES:  chronicrenalfailure <==> ['chronic renal failure' 'Disease' 'D007676'] 	 ***  chronicrenalfailure
# YES:  chronicrenalfailure <==> ['chronic renal failure' 'Disease' 'D007676'] 	 ***  chronicrenalfailure
# YES:  CRF <==> ['CRF' 'Disease' 'D007676'] 	 ***  crf
# YES:  risperidone <==> ['Risperidone' 'Chemical' 'D018967'] 	 ***  risperidone
# YES:  bleeding <==> ['bleeding' 'Disease' 'D006470'] 	 ***  bleeding
# YES:  CRF <==> ['CRF' 'Disease' 'D007676'] 	 ***  crf
# YES:  bleeding <==> ['bleeding' 'Disease' 'D006470'] 	 ***  bleeding
# YES:  Adrenaline <==> ['adrenaline' 'Chemical' 'D004837'] 	 ***  adrenaline
# YES:  hypertension <==> ['Hypertension' 'Disease' 'D006973'] 	 ***  hypertension
# YES:  adrenaline <==> ['adrenaline' 'Chemical' 'D004837'] 	 ***  adrenaline
# YES:  adrenaline <==> ['adrenaline' 'Chemical' 'D004837'] 	 ***  adrenaline
# YES:  seizure <==> ['Seizure' 'Disease' 'D012640'] 	 ***  seizure
# YES:  doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  cardiomyopathy <==> ['Cardiomyopathy' 'Disease' 'D009202'] 	 ***  cardiomyopathy
# YES:  cardiomyopathy <==> ['Cardiomyopathy' 'Disease' 'D009202'] 	 ***  cardiomyopathy
# YES:  doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  mitochondrialdysfunction <==> ['mitochondrial dysfunction' 'Disease' 'D028361'] 	 ***  mitochondrialdysfunction
# YES:  doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  toxicity <==> ['Toxicity' 'Disease' 'D064420'] 	 ***  toxicity
# YES:  doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  calcium <==> ['Calcium' 'Chemical' 'D002118'] 	 ***  calcium
# YES:  doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  Doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  Ca <==> ['Ca' 'Chemical' 'D002118'] 	 ***  ca
# YES:  doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  mitochondrialdysfunction <==> ['mitochondrial dysfunction' 'Disease' 'D028361'] 	 ***  mitochondrialdysfunction
# YES:  cardiomyopathy <==> ['Cardiomyopathy' 'Disease' 'D009202'] 	 ***  cardiomyopathy
# YES:  doxorubicin <==> ['Doxorubicin' 'Chemical' 'D004317'] 	 ***  doxorubicin
# YES:  cancer <==> ['Cancer' 'Disease' 'D009369'] 	 ***  cancer
# YES:  Cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  hyperactivity <==> ['hyperactivity' 'Disease' 'D006948'] 	 ***  hyperactivity
# ...
# YES:  hyperprolactinemia <==> ['Hyperprolactinemia' 'Disease' 'D006966'] 	 ***  hyperprolactinemia
# YES:  hyperprolactinemia <==> ['Hyperprolactinemia' 'Disease' 'D006966'] 	 ***  hyperprolactinemia
# YES:  dopamine <==> ['Dopamine' 'Chemical' 'D004298'] 	 ***  dopamine
# YES:  leukoencephalopathy <==> ['leukoencephalopathy' 'Disease' 'D056784'] 	 ***  leukoencephalopathy
# YES:  leukoencephalopathy <==> ['leukoencephalopathy' 'Disease' 'D056784'] 	 ***  leukoencephalopathy
# YES:  acutelymphoblasticleukemia <==> ['acute lymphoblastic leukemia' 'Disease' 'D054198'] 	 ***  acutelymphoblasticleukemia
# YES:  methotrexate <==> ['Methotrexate' 'Chemical' 'D008727'] 	 ***  methotrexate
# YES:  necrosis <==> ['necrosis' 'Disease' 'D009336'] 	 ***  necrosis
# YES:  leukoencephalopathy <==> ['leukoencephalopathy' 'Disease' 'D056784'] 	 ***  leukoencephalopathy
# YES:  Thrombotic <==> ['thrombotic' 'Disease' 'D013927'] 	 ***  thrombotic
# YES:  acuterenalfailure <==> ['acute renal failure' 'Disease' 'D058186'] 	 ***  acuterenalfailure
# YES:  tranexamicacid <==> ['Tranexamic acid' 'Chemical' 'D014148'] 	 ***  tranexamicacid
# YES:  acuterenalfailure <==> ['acute renal failure' 'Disease' 'D058186'] 	 ***  acuterenalfailure
# YES:  thromboembolic <==> ['thromboembolic' 'Disease' 'D013923'] 	 ***  thromboembolic
# YES:  acuterenalfailure <==> ['acute renal failure' 'Disease' 'D058186'] 	 ***  acuterenalfailure
# YES:  Thrombotic <==> ['thrombotic' 'Disease' 'D013927'] 	 ***  thrombotic
# YES:  heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  mania <==> ['mania' 'Disease' 'D001714'] 	 ***  mania
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  manic <==> ['Manic' 'Disease' 'D001714'] 	 ***  manic
# YES:  manic <==> ['Manic' 'Disease' 'D001714'] 	 ***  manic
# YES:  manic <==> ['Manic' 'Disease' 'D001714'] 	 ***  manic
# YES:  manic <==> ['Manic' 'Disease' 'D001714'] 	 ***  manic
# YES:  warfarin <==> ['Warfarin' 'Chemical' 'D014859'] 	 ***  warfarin
# YES:  warfarin <==> ['Warfarin' 'Chemical' 'D014859'] 	 ***  warfarin
# YES:  warfarin <==> ['Warfarin' 'Chemical' 'D014859'] 	 ***  warfarin
# YES:  heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  warfarin <==> ['Warfarin' 'Chemical' 'D014859'] 	 ***  warfarin
# YES:  warfarin <==> ['Warfarin' 'Chemical' 'D014859'] 	 ***  warfarin
# YES:  pain <==> ['Pain' 'Disease' 'D010146'] 	 ***  pain
# YES:  pain <==> ['Pain' 'Disease' 'D010146'] 	 ***  pain
# YES:  ibuprofen <==> ['ibuprofen' 'Chemical' 'D007052'] 	 ***  ibuprofen
# YES:  ibuprofen <==> ['ibuprofen' 'Chemical' 'D007052'] 	 ***  ibuprofen
# YES:  pain <==> ['Pain' 'Disease' 'D010146'] 	 ***  pain
# YES:  CO2 <==> ['CO2' 'Chemical' 'D002245'] 	 ***  co2
# YES:  pain <==> ['Pain' 'Disease' 'D010146'] 	 ***  pain
# YES:  pain <==> ['Pain' 'Disease' 'D010146'] 	 ***  pain
# YES:  CO2 <==> ['CO2' 'Chemical' 'D002245'] 	 ***  co2
# YES:  pain <==> ['Pain' 'Disease' 'D010146'] 	 ***  pain
# YES:  ibuprofen <==> ['ibuprofen' 'Chemical' 'D007052'] 	 ***  ibuprofen
# YES:  pain <==> ['Pain' 'Disease' 'D010146'] 	 ***  pain
# YES:  pain <==> ['Pain' 'Disease' 'D010146'] 	 ***  pain
# YES:  ibuprofen <==> ['ibuprofen' 'Chemical' 'D007052'] 	 ***  ibuprofen
# YES:  pain <==> ['Pain' 'Disease' 'D010146'] 	 ***  pain
# YES:  pain <==> ['Pain' 'Disease' 'D010146'] 	 ***  pain
# YES:  pain <==> ['Pain' 'Disease' 'D010146'] 	 ***  pain
# YES:  renaldamage <==> ['Renal damage' 'Disease' 'D007674'] 	 ***  renaldamage
# YES:  acuterenalfailure <==> ['acute renal failure' 'Disease' 'D058186'] 	 ***  acuterenalfailure
# YES:  aminoglycoside <==> ['Aminoglycoside' 'Chemical' 'D000617'] 	 ***  aminoglycoside
# YES:  renalfailure <==> ['renal failure' 'Disease' 'D051437'] 	 ***  renalfailure
# YES:  kanamycin <==> ['kanamycin' 'Chemical' 'D007612'] 	 ***  kanamycin
# YES:  renaldamage <==> ['Renal damage' 'Disease' 'D007674'] 	 ***  renaldamage
# YES:  aminoglycoside <==> ['Aminoglycoside' 'Chemical' 'D000617'] 	 ***  aminoglycoside
# YES:  renaldamage <==> ['Renal damage' 'Disease' 'D007674'] 	 ***  renaldamage
# YES:  nephrotoxicity <==> ['Nephrotoxicity' 'Disease' 'D007674'] 	 ***  nephrotoxicity
# YES:  depression <==> ['Depression' 'Disease' 'D003866'] 	 ***  depression
# YES:  postoperativenauseaandvomiting <==> ['postoperative nausea and vomiting' 'Disease' 'D020250'] 	 ***  postoperativenauseaandvomiting
# YES:  serotonin <==> ['serotonin' 'Chemical' 'D012701'] 	 ***  serotonin
# YES:  propofol <==> ['propofol' 'Chemical' 'D015742'] 	 ***  propofol
# YES:  serotonin <==> ['serotonin' 'Chemical' 'D012701'] 	 ***  serotonin
# YES:  nausea <==> ['nausea' 'Disease' 'D009325'] 	 ***  nausea
# YES:  Hypertensive <==> ['Hypertensive' 'Disease' 'D006973'] 	 ***  hypertensive
# YES:  dobutamine <==> ['Dobutamine' 'Chemical' 'D004280'] 	 ***  dobutamine
# YES:  dobutamine <==> ['Dobutamine' 'Chemical' 'D004280'] 	 ***  dobutamine
# YES:  hypertensive <==> ['Hypertensive' 'Disease' 'D006973'] 	 ***  hypertensive
# YES:  hypertension <==> ['Hypertension' 'Disease' 'D006973'] 	 ***  hypertension
# YES:  dobutamine <==> ['Dobutamine' 'Chemical' 'D004280'] 	 ***  dobutamine
# YES:  cardiacdysrhythmias <==> ['cardiac dysrhythmias' 'Disease' 'D001145'] 	 ***  cardiacdysrhythmias
# YES:  methotrexate <==> ['Methotrexate' 'Chemical' 'D008727'] 	 ***  methotrexate
# YES:  methotrexate <==> ['Methotrexate' 'Chemical' 'D008727'] 	 ***  methotrexate
# YES:  methotrexate <==> ['Methotrexate' 'Chemical' 'D008727'] 	 ***  methotrexate
# YES:  neurotoxic <==> ['neurotoxic' 'Disease' 'D020258'] 	 ***  neurotoxic
# YES:  methotrexate <==> ['Methotrexate' 'Chemical' 'D008727'] 	 ***  methotrexate
# YES:  methotrexate <==> ['Methotrexate' 'Chemical' 'D008727'] 	 ***  methotrexate
# YES:  methotrexate <==> ['Methotrexate' 'Chemical' 'D008727'] 	 ***  methotrexate
# YES:  methotrexate <==> ['Methotrexate' 'Chemical' 'D008727'] 	 ***  methotrexate
# YES:  toxicity <==> ['Toxicity' 'Disease' 'D064420'] 	 ***  toxicity
# YES:  neurotoxicity <==> ['Neurotoxicity' 'Disease' 'D020258'] 	 ***  neurotoxicity
# YES:  methotrexate <==> ['Methotrexate' 'Chemical' 'D008727'] 	 ***  methotrexate
# YES:  methotrexate <==> ['Methotrexate' 'Chemical' 'D008727'] 	 ***  methotrexate
# YES:  methotrexate <==> ['Methotrexate' 'Chemical' 'D008727'] 	 ***  methotrexate
# YES:  neurotoxicity <==> ['Neurotoxicity' 'Disease' 'D020258'] 	 ***  neurotoxicity
# YES:  lithium <==> ['Lithium' 'Chemical' 'D008094'] 	 ***  lithium
# YES:  lithium <==> ['Lithium' 'Chemical' 'D008094'] 	 ***  lithium
# YES:  polyuria <==> ['polyuria' 'Disease' 'D011141'] 	 ***  polyuria
# YES:  polydipsia <==> ['polydipsia' 'Disease' 'D059606'] 	 ***  polydipsia
# YES:  glucose <==> ['glucose' 'Chemical' 'D005947'] 	 ***  glucose
# YES:  glucose <==> ['glucose' 'Chemical' 'D005947'] 	 ***  glucose
# YES:  lithium <==> ['Lithium' 'Chemical' 'D008094'] 	 ***  lithium
# YES:  polyuria <==> ['polyuria' 'Disease' 'D011141'] 	 ***  polyuria
# YES:  dehydration <==> ['dehydration' 'Disease' 'D003681'] 	 ***  dehydration
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  chestpain <==> ['chest pain' 'Disease' 'D002637'] 	 ***  chestpain
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  Cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  cocaine <==> ['Cocaine' 'Chemical' 'D003042'] 	 ***  cocaine
# YES:  oxytocin <==> ['oxytocin' 'Chemical' 'D010121'] 	 ***  oxytocin
# YES:  abdominalpain <==> ['abdominal pain' 'Disease' 'D015746'] 	 ***  abdominalpain
# YES:  vomiting <==> ['vomiting' 'Disease' 'D014839'] 	 ***  vomiting
# YES:  Heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  thrombocytopenia <==> ['thrombocytopenia' 'Disease' 'D013921'] 	 ***  thrombocytopenia
# YES:  heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  thrombocytopenia <==> ['thrombocytopenia' 'Disease' 'D013921'] 	 ***  thrombocytopenia
# YES:  heparin <==> ['Heparin' 'Chemical' 'D006493'] 	 ***  heparin
# YES:  osteoporosis <==> ['osteoporosis' 'Disease' 'D010024'] 	 ***  osteoporosis
# YES:  eosinophilia <==> ['eosinophilia' 'Disease' 'D004802'] 	 ***  eosinophilia
# YES:  allergicreactions <==> ['allergic reactions' 'Disease' 'D004342'] 	 ***  allergicreactions
# YES:  thrombocytopenia <==> ['thrombocytopenia' 'Disease' 'D013921'] 	 ***  thrombocytopenia
# YES:  alopecia <==> ['Alopecia' 'Disease' 'D000505'] 	 ***  alopecia
# YES:  indinavir <==> ['indinavir' 'Chemical' 'D019469'] 	 ***  indinavir
# YES:  HIV-infected <==> ['HIV-infected' 'Disease' 'D015658'] 	 ***  hivinfected
# YES:  indinavir <==> ['indinavir' 'Chemical' 'D019469'] 	 ***  indinavir
# YES:  indinavir <==> ['indinavir' 'Chemical' 'D019469'] 	 ***  indinavir
# YES:  indinavir <==> ['indinavir' 'Chemical' 'D019469'] 	 ***  indinavir
# YES:  sumatriptan <==> ['sumatriptan' 'Chemical' 'D018170'] 	 ***  sumatriptan
# YES:  serotonin <==> ['serotonin' 'Chemical' 'D012701'] 	 ***  serotonin
# YES:  5-hydroxytryptamine <==> ['5-hydroxytryptamine' 'Chemical' 'D012701'] 	 ***  5hydroxytryptamine
# YES:  myocardialischemia <==> ['myocardial ischemia' 'Disease' 'D017202'] 	 ***  myocardialischemia
# YES:  myocardialinfarction <==> ['Myocardial infarction' 'Disease' 'D009203'] 	 ***  myocardialinfarction
# YES:  sumatriptan <==> ['sumatriptan' 'Chemical' 'D018170'] 	 ***  sumatriptan
# YES:  migraine <==> ['Migraine' 'Disease' 'D008881'] 	 ***  migraine
# YES:  sumatriptan <==> ['sumatriptan' 'Chemical' 'D018170'] 	 ***  sumatriptan
# YES:  Parkinson'sdisease <==> ["Parkinson's Disease" 'Disease' 'D010300'] 	 ***  parkinsonsdisease
# YES:  rigidity <==> ['rigidity' 'Disease' 'D009127'] 	 ***  rigidity
# YES:  L-DOPA <==> ['L-DOPA' 'Chemical' 'D007980'] 	 ***  ldopa
# YES:  dyskinesias <==> ['dyskinesias' 'Disease' 'D004409'] 	 ***  dyskinesias
# YES:  Parkinson'sDisease <==> ["Parkinson's Disease" 'Disease' 'D010300'] 	 ***  parkinsonsdisease
# YES:  dyskinesias <==> ['dyskinesias' 'Disease' 'D004409'] 	 ***  dyskinesias
# YES:  rigidity <==> ['rigidity' 'Disease' 'D009127'] 	 ***  rigidity
# YES:  Parkinson'sdisease <==> ["Parkinson's Disease" 'Disease' 'D010300'] 	 ***  parkinsonsdisease
# YES:  bleeding <==> ['bleeding' 'Disease' 'D006470'] 	 ***  bleeding
# YES:  carbachol <==> ['Carbachol' 'Chemical' 'D002217'] 	 ***  carbachol
# YES:  carbachol <==> ['Carbachol' 'Chemical' 'D002217'] 	 ***  carbachol
# YES:  hexamethonium <==> ['hexamethonium' 'Chemical' 'D018738'] 	 ***  hexamethonium
# YES:  phentolamine <==> ['phentolamine' 'Chemical' 'D010646'] 	 ***  phentolamine
# YES:  propranolol <==> ['propranolol' 'Chemical' 'D011433'] 	 ***  propranolol
# YES:  tachycardia <==> ['tachycardia' 'Disease' 'D013610'] 	 ***  tachycardia
# YES:  carbachol <==> ['Carbachol' 'Chemical' 'D002217'] 	 ***  carbachol
# YES:  carbachol <==> ['Carbachol' 'Chemical' 'D002217'] 	 ***  carbachol
# YES:  atropine <==> ['Atropine' 'Chemical' 'D001285'] 	 ***  atropine
# YES:  hexamethonium <==> ['hexamethonium' 'Chemical' 'D018738'] 	 ***  hexamethonium
# YES:  chlorpromazine <==> ['chlorpromazine' 'Chemical' 'D002746'] 	 ***  chlorpromazine
# YES:  carbachol <==> ['Carbachol' 'Chemical' 'D002217'] 	 ***  carbachol
# YES:  carbachol <==> ['Carbachol' 'Chemical' 'D002217'] 	 ***  carbachol
# YES:  methylphenidate <==> ['Methylphenidate' 'Chemical' 'D008774'] 	 ***  methylphenidate
# YES:  methylphenidate <==> ['Methylphenidate' 'Chemical' 'D008774'] 	 ***  methylphenidate
# YES:  methylphenidate <==> ['Methylphenidate' 'Chemical' 'D008774'] 	 ***  methylphenidate
# YES:  dopamine <==> ['Dopamine' 'Chemical' 'D004298'] 	 ***  dopamine
# YES:  dopamine <==> ['Dopamine' 'Chemical' 'D004298'] 	 ***  dopamine
# YES:  gamma-aminobutyricacid <==> ['gamma-aminobutyric acid' 'Chemical' 'D005680'] 	 ***  gammaaminobutyricacid
# YES:  diazepam <==> ['Diazepam' 'Chemical' 'D003975'] 	 ***  diazepam
# YES:  gamma-aminobutyricacid <==> ['gamma-aminobutyric acid' 'Chemical' 'D005680'] 	 ***  gammaaminobutyricacid
# YES:  methylphenidate <==> ['Methylphenidate' 'Chemical' 'D008774'] 	 ***  methylphenidate
# YES:  EE <==> ['EE' 'Chemical' 'D004997'] 	 ***  ee
# YES:  cholesterol <==> ['cholesterol' 'Chemical' 'D002784'] 	 ***  cholesterol
# YES:  EE <==> ['EE' 'Chemical' 'D004997'] 	 ***  ee
# YES:  EE <==> ['EE' 'Chemical' 'D004997'] 	 ***  ee
# YES:  EE <==> ['EE' 'Chemical' 'D004997'] 	 ***  ee
# YES:  EE <==> ['EE' 'Chemical' 'D004997'] 	 ***  ee
# YES:  EE <==> ['EE' 'Chemical' 'D004997'] 	 ***  ee
# YES:  EE <==> ['EE' 'Chemical' 'D004997'] 	 ***  ee
# YES:  EE <==> ['EE' 'Chemical' 'D004997'] 	 ***  ee
# YES:  EE <==> ['EE' 'Chemical' 'D004997'] 	 ***  ee
# YES:  EE <==> ['EE' 'Chemical' 'D004997'] 	 ***  ee
# YES:  EE <==> ['EE' 'Chemical' 'D004997'] 	 ***  ee
# YES:  intrahepaticcholestasis <==> ['intrahepatic cholestasis' 'Disease' 'D002780'] 	 ***  intrahepaticcholestasis
# YES:  EE <==> ['EE' 'Chemical' 'D004997'] 	 ***  ee
# YES:  hypotension <==> ['Hypotension' 'Disease' 'D007022'] 	 ***  hypotension
# YES:  aminoacid <==> ['amino acid' 'Chemical' 'D000596'] 	 ***  aminoacid
# YES:  ATP <==> ['ATP' 'Chemical' 'D000255'] 	 ***  atp
# YES:  K <==> ['K' 'Chemical' 'D011188'] 	 ***  k
# YES:  K <==> ['K' 'Chemical' 'D011188'] 	 ***  k
# YES:  ATP <==> ['ATP' 'Chemical' 'D000255'] 	 ***  atp
# YES:  hypotension <==> ['Hypotension' 'Disease' 'D007022'] 	 ***  hypotension
# YES:  Hypotension <==> ['Hypotension' 'Disease' 'D007022'] 	 ***  hypotension
# YES:  hypotension <==> ['Hypotension' 'Disease' 'D007022'] 	 ***  hypotension
# YES:  acetylcholine <==> ['acetylcholine' 'Chemical' 'D000109'] 	 ***  acetylcholine
# YES:  ACh <==> ['ACh' 'Chemical' 'D000109'] 	 ***  ach
# YES:  hypotension <==> ['Hypotension' 'Disease' 'D007022'] 	 ***  hypotension
# YES:  hypotension <==> ['Hypotension' 'Disease' 'D007022'] 	 ***  hypotension
# YES:  K <==> ['K' 'Chemical' 'D011188'] 	 ***  k
# YES:  K <==> ['K' 'Chemical' 'D011188'] 	 ***  k
# YES:  ATP <==> ['ATP' 'Chemical' 'D000255'] 	 ***  atp
# YES:  nitricoxide <==> ['nitric oxide' 'Chemical' 'D009569'] 	 ***  nitricoxide
# YES:  hypotension <==> ['Hypotension' 'Disease' 'D007022'] 	 ***  hypotension
# YES:  nifedipine <==> ['Nifedipine' 'Chemical' 'D009543'] 	 ***  nifedipine
# YES:  cyclosporinA <==> ['cyclosporin A' 'Chemical' 'D016572'] 	 ***  cyclosporina
# YES:  hypertension <==> ['Hypertension' 'Disease' 'D006973'] 	 ***  hypertension
# YES:  psoriasis <==> ['psoriasis' 'Disease' 'D011565'] 	 ***  psoriasis
# YES:  hypertension <==> ['Hypertension' 'Disease' 'D006973'] 	 ***  hypertension
# YES:  cyclosporinA <==> ['cyclosporin A' 'Chemical' 'D016572'] 	 ***  cyclosporina
# YES:  calcium <==> ['Calcium' 'Chemical' 'D002118'] 	 ***  calcium
# YES:  nifedipine <==> ['Nifedipine' 'Chemical' 'D009543'] 	 ***  nifedipine
# YES:  hypertensive <==> ['Hypertensive' 'Disease' 'D006973'] 	 ***  hypertensive
# YES:  cyclosporinA <==> ['cyclosporin A' 'Chemical' 'D016572'] 	 ***  cyclosporina
# YES:  nifedipine <==> ['Nifedipine' 'Chemical' 'D009543'] 	 ***  nifedipine
# YES:  cyclosporinA <==> ['cyclosporin A' 'Chemical' 'D016572'] 	 ***  cyclosporina
# YES:  nifedipine <==> ['Nifedipine' 'Chemical' 'D009543'] 	 ***  nifedipine
# YES:  bloodureanitrogen <==> ['blood urea nitrogen' 'Chemical' 'D001806'] 	 ***  bloodureanitrogen
# YES:  nifedipine <==> ['Nifedipine' 'Chemical' 'D009543'] 	 ***  nifedipine
# YES:  hypertensive <==> ['Hypertensive' 'Disease' 'D006973'] 	 ***  hypertensive
# YES:  cyclosporinA <==> ['cyclosporin A' 'Chemical' 'D016572'] 	 ***  cyclosporina
# ---------------------------------------------------
# DATASET test
# Total  :  9809
# Matched:  6134
# Unique concept counts:
# Total  :  2341
# Matched:  841
# Time taken:  3.09945702553 sec

# %%
######################################################################################################
# Print table with results: # matched NEs; several table variants
######################################################################################################

import numpy as np
import time
import glob
from tabulate import tabulate

methods = [
    'E1', 'E2', 'A1', 'A2', 'A3', 'Total # NEs'
]
sets = [
    'Training set', 'Development set', 'Test set'
]
mat = np.array([
    [7113, 5037, 5014],
    [8779, 5682, 5682],
    [9309, 5848, 5845],
    [9309, 6085, 6101],
    [9309, 6098, 6134],
    
    [9385, 9591, 9809], # total

])

tab_header = ['Abstraction method'] + sets
print tabulate(mat, 
               headers=tab_header, tablefmt='fancy_grid', showindex=methods,
               numalign='center')#, floatfmt=(".4f", ".4f", ".4f", ".4f", ".4f", ".4f", ".6f"))
print tabulate(mat, 
               headers=tab_header, tablefmt='latex_booktabs', showindex=methods,
               numalign='center')#, floatfmt=(".4f", ".4f", ".4f", ".4f", ".4f", ".4f", ".6f"))
######################################################################################################
methods = [
    'E1', 'E2', 'A1', 'A2', 'A3'
]
sets = [
    'Training set', 'Development set', 'Test set'
]
mat = np.array([
    [7113, 5037, 5014],
    [8779, 5682, 5682],
    [9309, 5848, 5845],
    [9309, 6085, 6101],
    [9309, 6098, 6134],
])
mat = mat / np.array([9385., 9591., 9809.])

tab_header = ['Abstraction method'] + sets
print tabulate(mat, 
               headers=tab_header, tablefmt='fancy_grid', showindex=methods,
               numalign='center', floatfmt=(".4f", ".4f", ".4f", ".4f", ".4f", ".4f", ".6f"))
print tabulate(mat, 
               headers=tab_header, tablefmt='latex_booktabs', showindex=methods,
               numalign='center', floatfmt=(".4f", ".4f", ".4f", ".4f", ".4f", ".4f", ".6f"))
######################################################################################################
methods = [
    'E1', 'E2', 'A1', 'A2', 'A3', 'Total # NEs'
]
sets = [
    'Training set', 'Development set', 'Test set'
]
mat = np.array([
    [7113, 5037, 5014],
    [8779, 5682, 5682],
    [9309, 5848, 5845],
    [9309, 6085, 6101],
    [9309, 6098, 6134],
    [9385**2, 9591**2, 9809**2], # total
])
mat = mat / np.array([9385., 9591., 9809.])

tab_header = ['Abstraction method'] + sets
print tabulate(mat, 
               headers=tab_header, tablefmt='fancy_grid', showindex=methods,
               numalign='center', floatfmt=(".3f", ".3f", ".3f", ".3f", ".3f", ".3f", ".3f"))
#                numalign='center', floatfmt=(".4f", ".4f", ".4f", ".4f", ".4f", ".4f", ".6f"))
print tabulate(mat, 
               headers=tab_header, tablefmt='latex_booktabs', showindex=methods,
               numalign='center', floatfmt=(".3f", ".3f", ".3f", ".3f", ".3f", ".3f", ".3f"))
# Out:
# ╒══════════════════════╤════════════════╤═══════════════════╤════════════╕
# │ Abstraction method   │  Training set  │  Development set  │  Test set  │
# ╞══════════════════════╪════════════════╪═══════════════════╪════════════╡
# │ E1                   │      7113      │       5037        │    5014    │
# ├──────────────────────┼────────────────┼───────────────────┼────────────┤
# │ E2                   │      8779      │       5682        │    5682    │
# ├──────────────────────┼────────────────┼───────────────────┼────────────┤
# │ A1                   │      9309      │       5848        │    5845    │
# ├──────────────────────┼────────────────┼───────────────────┼────────────┤
# │ A2                   │      9309      │       6085        │    6101    │
# ├──────────────────────┼────────────────┼───────────────────┼────────────┤
# │ A3                   │      9309      │       6098        │    6134    │
# ├──────────────────────┼────────────────┼───────────────────┼────────────┤
# │ Total # NEs          │      9385      │       9591        │    9809    │
# ╘══════════════════════╧════════════════╧═══════════════════╧════════════╛
# \begin{tabular}{lccc}
# \toprule
#  Abstraction method   &  Training set  &  Development set  &  Test set  \\
# \midrule
#  E1                   &      7113      &       5037        &    5014    \\
#  E2                   &      8779      &       5682        &    5682    \\
#  A1                   &      9309      &       5848        &    5845    \\
#  A2                   &      9309      &       6085        &    6101    \\
#  A3                   &      9309      &       6098        &    6134    \\
#  Total \# NEs          &      9385      &       9591        &    9809    \\
# \bottomrule
# \end{tabular}
# ╒══════════════════════╤════════════════╤═══════════════════╤════════════╕
# │ Abstraction method   │  Training set  │  Development set  │  Test set  │
# ╞══════════════════════╪════════════════╪═══════════════════╪════════════╡
# │ E1                   │     0.7579     │      0.5252       │   0.5112   │
# ├──────────────────────┼────────────────┼───────────────────┼────────────┤
# │ E2                   │     0.9354     │      0.5924       │   0.5793   │
# ├──────────────────────┼────────────────┼───────────────────┼────────────┤
# │ A1                   │     0.9919     │      0.6097       │   0.5959   │
# ├──────────────────────┼────────────────┼───────────────────┼────────────┤
# │ A2                   │     0.9919     │      0.6344       │   0.6220   │
# ├──────────────────────┼────────────────┼───────────────────┼────────────┤
# │ A3                   │     0.9919     │      0.6358       │   0.6253   │
# ╘══════════════════════╧════════════════╧═══════════════════╧════════════╛
# \begin{tabular}{lccc}
# \toprule
#  Abstraction method   &  Training set  &  Development set  &  Test set  \\
# \midrule
#  E1                   &     0.7579     &      0.5252       &   0.5112   \\
#  E2                   &     0.9354     &      0.5924       &   0.5793   \\
#  A1                   &     0.9919     &      0.6097       &   0.5959   \\
#  A2                   &     0.9919     &      0.6344       &   0.6220   \\
#  A3                   &     0.9919     &      0.6358       &   0.6253   \\
# \bottomrule
# \end{tabular}
# ╒══════════════════════╤════════════════╤═══════════════════╤════════════╕
# │ Abstraction method   │  Training set  │  Development set  │  Test set  │
# ╞══════════════════════╪════════════════╪═══════════════════╪════════════╡
# │ E1                   │     0.758      │       0.525       │   0.511    │
# ├──────────────────────┼────────────────┼───────────────────┼────────────┤
# │ E2                   │     0.935      │       0.592       │   0.579    │
# ├──────────────────────┼────────────────┼───────────────────┼────────────┤
# │ A1                   │     0.992      │       0.610       │   0.596    │
# ├──────────────────────┼────────────────┼───────────────────┼────────────┤
# │ A2                   │     0.992      │       0.634       │   0.622    │
# ├──────────────────────┼────────────────┼───────────────────┼────────────┤
# │ A3                   │     0.992      │       0.636       │   0.625    │
# ├──────────────────────┼────────────────┼───────────────────┼────────────┤
# │ Total # NEs          │    9385.000    │     9591.000      │  9809.000  │
# ╘══════════════════════╧════════════════╧═══════════════════╧════════════╛
# \begin{tabular}{lccc}
# \toprule
#  Abstraction method   &  Training set  &  Development set  &  Test set  \\
# \midrule
#  E1                   &     0.758      &       0.525       &   0.511    \\
#  E2                   &     0.935      &       0.592       &   0.579    \\
#  A1                   &     0.992      &       0.610       &   0.596    \\
#  A2                   &     0.992      &       0.634       &   0.622    \\
#  A3                   &     0.992      &       0.636       &   0.625    \\
#  Total \# NEs          &    9385.000    &     9591.000      &  9809.000  \\
# \bottomrule
# \end{tabular}
